# %%
# https://www.relataly.com/crypto-market-cluster-analysis-using-affinity-propagation-python/8114/

# %%
# ! pip install cryptocmd
# ! pip install seaborn

# %%
from cryptocmd import CmcScraper
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns
from sklearn import cluster, covariance, manifold
import requests
import json

# %%
NUMBER_OF_CRYPTOCURRENCIES = 500
TIMEOUT = 10 # seconds

# %%
# get a dictionary of the top 500 coin symbols and names from an API

# def get_symbol_dict():
url = f'https://api.coinmarketcap.com/data-api/v3/cryptocurrency/listing?start=1&limit={NUMBER_OF_CRYPTOCURRENCIES}&sortBy=market_cap&sortType=desc&convert=USD&cryptoType=all&tagType=all&audited=false'
response = requests.get(url, timeout = TIMEOUT)
data = json.loads(response.text)
cryptoBasicData = pd.DataFrame(data['data']['cryptoCurrencyList'])
cryptoBasicData.to_csv('./')
# Out:
#      id      name symbol      slug  \
# 0     1   Bitcoin    BTC   bitcoin
# 1  1027  Ethereum    ETH  ethereum
# 2   825    Tether   USDT    tether
# 3  1839       BNB    BNB       bnb
# 4  3408  USD Coin   USDC  usd-coin
#
#                                                 tags  cmcRank  \
# 0  [mineable, pow, sha-256, store-of-value, state...        1
# 1  [pos, smart-contracts, ethereum-ecosystem, coi...        2
# 2  [payments, stablecoin, asset-backed-stablecoin...        3
# 3  [marketplace, centralized-exchange, payments, ...        4
# 4  [medium-of-exchange, stablecoin, asset-backed-...        5
#
#    marketPairCount  circulatingSupply  selfReportedCirculatingSupply  \
# 0            10207       1.936911e+07                            0.0
# 1             6858       1.203177e+08                            0.0
# 2            53073       8.247941e+10                            0.0
# 3             1348       1.558608e+08                            0.0
# 4            12312       3.016294e+10                            0.0
#
#     totalSupply   maxSupply  isActive               lastUpdated  \
# 0  1.936911e+07  21000000.0         1  2023-05-10T11:42:00.000Z
# 1  1.203177e+08         NaN         1  2023-05-10T11:42:00.000Z
# 2  8.609064e+10         NaN         1  2023-05-10T11:42:00.000Z
# 3  1.558608e+08         NaN         1  2023-05-10T11:42:00.000Z
# 4  3.016294e+10         NaN         1  2023-05-10T11:42:00.000Z
#
#                   dateAdded  \
# 0  2010-07-13T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2015-02-25T00:00:00.000Z
# 3  2017-07-25T00:00:00.000Z
# 4  2018-10-08T00:00:00.000Z
#
#                                               quotes  isAudited  \
# 0  [{'name': 'USD', 'price': 27621.550556541348, ...      False
# 1  [{'name': 'USD', 'price': 1847.3121867016382, ...      False
# 2  [{'name': 'USD', 'price': 1.0003896962518632, ...       True
# 3  [{'name': 'USD', 'price': 311.23214328696605, ...       True
# 4  [{'name': 'USD', 'price': 0.9999639771346835, ...      False
#
#                                        auditInfoList  \
# 0                                                NaN
# 1                                                 []
# 2  [{'coinId': '825', 'auditor': 'CertiK', 'audit...
# 3  [{'coinId': '1839', 'auditor': 'CertiK', 'audi...
# 4                                                NaN
#
#                                             platform
# 0                                                NaN
# 1                                                NaN
# 2  {'id': 1, 'name': 'Ethereum', 'symbol': 'ETH',...
# 3                                                NaN
# 4                                                NaN
