# %%
from json import dump, load
from os import getenv, listdir
import pandas as pd
from requests import get
from time import sleep

# %%
AV_API = getenv('AV_API')

# %%
currencies = pd.read_csv('./currency_list.csv')
currencies
# Out:
#     currency_code currency_name
# 0             1ST    FirstBlood
# 1           2GIVE      GiveCoin
# 2             808       808Coin
# 3            AAVE          Aave
# 4             ABT      ArcBlock
# ..            ...           ...
# 570           ZEN       ZenCash
# 571           ZET      Zetacoin
# 572           ZIL       Zilliqa
# 573           ZLA         Zilla
# 574           ZRX            0x
#
# [575 rows x 2 columns]

# %%
try:
    allData = pd.read_csv('./data/all_data.csv')
except FileNotFoundError:
    allData = pd.DataFrame()
else:
    allData = allData.iloc[: , 1:]

for timeFrame in ('daily', 'weekly', 'monthly'):
    for symbol in currencies['currency_code']:

        if f'{timeFrame}_{symbol}.csv' in listdir('./data/'):
            continue

        url = f'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_{timeFrame.upper()}&symbol={symbol}&market=USD&apikey={AV_API}&datatype=csv'
        
        try:
            response = get(url, timeout = 60)
        except:
            print(f'{timeFrame} {symbol} connection error.')
            continue
        
        sleep(15)

        if 'API' in response.text:
            print(f'{timeFrame} {symbol} reached to API limit.')
            continue

        print(f'{timeFrame} {symbol} {response}')

        if response.status_code == 200:
            with open(f'./data/{timeFrame}_{symbol}.csv', 'wb') as dataFile:
                dataFile.write(response.content)
        else:
            print(f'{timeFrame} {symbol} not responding correctly.')
            continue

        data = pd.read_csv(f'./data/{timeFrame}_{symbol}.csv')
        data['time_frame'] = timeFrame
        data['symbol'] = symbol

        allData = pd.concat([allData, data])
        allData.reset_index(drop = True, inplace = True)
        allData.to_csv('./data/all_data.csv')

allData
# Out:
# daily 1ST reached to API limit.
# daily 2GIVE reached to API limit.
# daily 808 reached to API limit.
# daily AAVE <Response [200]>
# daily ABT reached to API limit.
# daily ABY reached to API limit.
# daily AC reached to API limit.
# daily ACT reached to API limit.
# daily ADA <Response [200]>
# daily ADT reached to API limit.
# daily ADX <Response [200]>
# daily AE reached to API limit.
# daily AEON reached to API limit.
# daily AGI reached to API limit.
# daily AGRS reached to API limit.
# daily AI reached to API limit.
# daily AID reached to API limit.
# daily AION <Response [200]>
# daily AIR reached to API limit.
# daily AKY reached to API limit.
# daily ALGO <Response [200]>
# daily ALIS reached to API limit.
# daily AMBER reached to API limit.
# daily AMP <Response [200]>
# daily AMPL reached to API limit.
# daily ANC <Response [200]>
# daily ANT <Response [200]>
# daily APPC reached to API limit.
# daily APX reached to API limit.
# daily ARDR <Response [200]>
# daily ARK reached to API limit.
# daily ARN reached to API limit.
# daily AST reached to API limit.
# daily ATB reached to API limit.
# daily ATM <Response [200]>
# daily ATOM <Response [200]>
# daily ATS reached to API limit.
# daily AUR reached to API limit.
# daily AVAX <Response [200]>
# daily AVT reached to API limit.
# daily B3 reached to API limit.
# daily BAND <Response [200]>
# daily BAT <Response [200]>
# daily BAY reached to API limit.
# daily BBR reached to API limit.
# daily BCAP reached to API limit.
# daily BCC <Response [200]>
# daily BCD reached to API limit.
# daily BCH <Response [200]>
# daily BCN reached to API limit.
# daily BCPT reached to API limit.
# daily BCX reached to API limit.
# daily BCY reached to API limit.
# daily BDL reached to API limit.
# daily BEE reached to API limit.
# daily BELA reached to API limit.
# daily BET reached to API limit.
# daily BFT reached to API limit.
# daily BIS reached to API limit.
# daily BITB reached to API limit.
# daily BITBTC reached to API limit.
# daily BITCNY reached to API limit.
# daily BITEUR reached to API limit.
# daily BITGOLD reached to API limit.
# daily BITSILVER reached to API limit.
# daily BITUSD reached to API limit.
# daily BIX reached to API limit.
# daily BLITZ reached to API limit.
# daily BLK reached to API limit.
# daily BLN reached to API limit.
# daily BLOCK reached to API limit.
# daily BLZ <Response [200]>
# daily BMC reached to API limit.
# daily BNB <Response [200]>
# daily BNT <Response [200]>
# daily BNTY reached to API limit.
# daily BOST reached to API limit.
# daily BOT reached to API limit.
# daily BQ reached to API limit.
# daily BRD reached to API limit.
# daily BRK reached to API limit.
# daily BRX reached to API limit.
# daily BSV reached to API limit.
# daily BTA reached to API limit.
# daily BTC <Response [200]>
# daily BTCB reached to API limit.
# daily BTCD reached to API limit.
# daily BTCP reached to API limit.
# daily BTG <Response [200]>
# daily BTM reached to API limit.
# daily BTS <Response [200]>
# daily BTSR reached to API limit.
# daily BTT <Response [200]>
# daily BTX reached to API limit.
# daily BURST reached to API limit.
# daily BUSD <Response [200]>
# daily BUZZ reached to API limit.
# daily BYC reached to API limit.
# daily BYTOM reached to API limit.
# daily C20 reached to API limit.
# daily CAKE <Response [200]>
# daily CANN reached to API limit.
# daily CAT reached to API limit.
# daily CCRB reached to API limit.
# daily CDT reached to API limit.
# daily CFI reached to API limit.
# daily CHAT reached to API limit.
# daily CHIPS reached to API limit.
# daily CLAM reached to API limit.
# daily CLOAK reached to API limit.
# daily CMP reached to API limit.
# daily CMT reached to API limit.
# daily CND reached to API limit.
# daily CNX reached to API limit.
# daily COFI reached to API limit.
# daily COMP <Response [200]>
# daily COSS reached to API limit.
# daily COVAL reached to API limit.
# daily CRBIT reached to API limit.
# daily CREA reached to API limit.
# daily CREDO reached to API limit.
# daily CRO reached to API limit.
# daily CRW reached to API limit.
# daily CSNO reached to API limit.
# daily CTR reached to API limit.
# daily CTXC <Response [200]>
# daily CURE reached to API limit.
# daily CVC <Response [200]>
# daily DAI <Response [200]>
# daily DAR <Response [200]>
# daily DASH <Response [200]>
# daily DATA <Response [200]>
# daily DAY reached to API limit.
# daily DBC reached to API limit.
# daily DBIX reached to API limit.
# daily DCN reached to API limit.
# daily DCR <Response [200]>
# daily DCT reached to API limit.
# daily DDF reached to API limit.
# daily DENT <Response [200]>
# daily DFS reached to API limit.
# daily DGB <Response [200]>
# daily DGC reached to API limit.
# daily DGD reached to API limit.
# daily DICE reached to API limit.
# daily DLT reached to API limit.
# daily DMD reached to API limit.
# daily DMT reached to API limit.
# daily DNT <Response [200]>
# daily DOGE <Response [200]>
# daily DOPE reached to API limit.
# daily DOT <Response [200]>
# daily DRGN reached to API limit.
# daily DTA reached to API limit.
# daily DTB reached to API limit.
# daily DYN reached to API limit.
# daily EAC reached to API limit.
# daily EBST reached to API limit.
# daily EBTC reached to API limit.
# daily ECC reached to API limit.
# daily ECN reached to API limit.
# daily EDG reached to API limit.
# daily EDO reached to API limit.
# daily EFL reached to API limit.
# daily EGC reached to API limit.
# daily EGLD <Response [200]>
# daily EKT reached to API limit.
# daily ELA reached to API limit.
# daily ELEC reached to API limit.
# daily ELF <Response [200]>
# daily ELIX reached to API limit.
# daily EMB reached to API limit.
# daily EMC reached to API limit.
# daily EMC2 reached to API limit.
# daily ENG reached to API limit.
# daily ENJ <Response [200]>
# daily ENRG reached to API limit.
# daily EOS <Response [200]>
# daily EOT reached to API limit.
# daily EQT reached to API limit.
# daily ERC reached to API limit.
# daily ETC <Response [200]>
# daily ETH <Response [200]>
# daily ETHD reached to API limit.
# daily ETHOS reached to API limit.
# daily ETN reached to API limit.
# daily ETP reached to API limit.
# daily ETT reached to API limit.
# daily EVE reached to API limit.
# daily EVX reached to API limit.
# daily EXCL reached to API limit.
# daily EXP reached to API limit.
# daily FCT reached to API limit.
# daily FIL <Response [200]>
# daily FLDC reached to API limit.
# daily FLO reached to API limit.
# daily FLT reached to API limit.
# daily FRST reached to API limit.
# daily FTC reached to API limit.
# daily FTT <Response [200]>
# daily FUEL reached to API limit.
# daily FUN <Response [200]>
# daily GAM reached to API limit.
# daily GAME reached to API limit.
# daily GAS <Response [200]>
# daily GBG reached to API limit.
# daily GBX reached to API limit.
# daily GBYTE reached to API limit.
# daily GCR reached to API limit.
# daily GEO reached to API limit.
# daily GLD reached to API limit.
# daily GNO <Response [200]>
# daily GNT reached to API limit.
# daily GOLOS reached to API limit.
# daily GRC reached to API limit.
# daily GRT <Response [200]>
# daily GRS reached to API limit.
# daily GRWI reached to API limit.
# daily GTC <Response [200]>
# daily GTO <Response [200]>
# daily GUP reached to API limit.
# daily GVT reached to API limit.
# daily GXS <Response [200]>
# daily HBAR reached to API limit.
# daily HBN reached to API limit.
# daily HEAT reached to API limit.
# daily HMQ reached to API limit.
# daily HPB reached to API limit.
# daily HSR reached to API limit.
# daily HT reached to API limit.
# daily HUSH reached to API limit.
# daily HVN reached to API limit.
# daily HXX reached to API limit.
# daily ICN reached to API limit.
# daily ICX <Response [200]>
# daily IFC reached to API limit.
# daily IFT reached to API limit.
# daily IGNIS reached to API limit.
# daily INCNT reached to API limit.
# daily IND reached to API limit.
# daily INF reached to API limit.
# daily INK reached to API limit.
# daily INS reached to API limit.
# daily INSTAR reached to API limit.
# daily INT reached to API limit.
# daily INXT reached to API limit.
# daily IOC reached to API limit.
# daily ION reached to API limit.
# daily IOP reached to API limit.
# daily IOST <Response [200]>
# daily IOTA <Response [200]>
# daily IOTX <Response [200]>
# daily IQT reached to API limit.
# daily ITC reached to API limit.
# daily IXC reached to API limit.
# daily IXT reached to API limit.
# daily J8T reached to API limit.
# daily JNT reached to API limit.
# daily KCS reached to API limit.
# daily KICK reached to API limit.
# daily KIN reached to API limit.
# daily KLAY reached to API limit.
# daily KMD <Response [200]>
# daily KNC <Response [200]>
# daily KORE reached to API limit.
# daily KSM <Response [200]>
# daily LBC reached to API limit.
# daily LCC reached to API limit.
# daily LEND <Response [200]>
# daily LEO reached to API limit.
# daily LEV reached to API limit.
# daily LGD reached to API limit.
# daily LINDA reached to API limit.
# daily LINK <Response [200]>
# daily LKK reached to API limit.
# daily LMC reached to API limit.
# daily LOCI reached to API limit.
# daily LOOM <Response [200]>
# daily LRC <Response [200]>
# daily LSK <Response [200]>
# daily LTC <Response [200]>
# daily LUN reached to API limit.
# daily LUNA <Response [200]>
# daily MAID reached to API limit.
# daily MANA <Response [200]>
# daily MATIC <Response [200]>
# daily MAX reached to API limit.
# daily MBRS reached to API limit.
# daily MCAP reached to API limit.
# daily MCO <Response [200]>
# daily MDA reached to API limit.
# daily MEC reached to API limit.
# daily MED reached to API limit.
# daily MEME reached to API limit.
# daily MER reached to API limit.
# daily MGC reached to API limit.
# daily MGO reached to API limit.
# daily MINEX reached to API limit.
# daily MINT reached to API limit.
# daily MIOTA reached to API limit.
# daily MITH <Response [200]>
# daily MKR <Response [200]>
# daily MLN <Response [200]>
# daily MNE reached to API limit.
# daily MNX reached to API limit.
# daily MOD reached to API limit.
# daily MONA reached to API limit.
# daily MRT reached to API limit.
# daily MSP reached to API limit.
# daily MTH reached to API limit.
# daily MTN reached to API limit.
# daily MUE reached to API limit.
# daily MUSIC reached to API limit.
# daily MYB reached to API limit.
# daily MYST reached to API limit.
# daily MZC reached to API limit.
# daily NAMO reached to API limit.
# daily NANO <Response [200]>
# daily NAS reached to API limit.
# daily NAV reached to API limit.
# daily NBT <Response [200]>
# daily NCASH reached to API limit.
# daily NDC reached to API limit.
# daily NEBL <Response [200]>
# daily NEO <Response [200]>
# daily NEOS reached to API limit.
# daily NET reached to API limit.
# daily NLC2 reached to API limit.
# daily NLG reached to API limit.
# daily NMC reached to API limit.
# daily NMR <Response [200]>
# daily NOBL reached to API limit.
# daily NOTE reached to API limit.
# daily NPXS <Response [200]>
# daily NSR reached to API limit.
# daily NTO reached to API limit.
# daily NULS <Response [200]>
# daily NVC reached to API limit.
# daily NXC reached to API limit.
# daily NXS reached to API limit.
# daily NXT reached to API limit.
# daily OAX <Response [200]>
# daily OBITS reached to API limit.
# daily OCL reached to API limit.
# daily OCN reached to API limit.
# daily ODEM reached to API limit.
# daily ODN reached to API limit.
# daily OF reached to API limit.
# daily OK reached to API limit.
# daily OMG <Response [200]>
# daily OMNI reached to API limit.
# daily ONION reached to API limit.
# daily ONT <Response [200]>
# daily OPT reached to API limit.
# daily ORN <Response [200]>
# daily OST reached to API limit.
# daily PART reached to API limit.
# daily PASC reached to API limit.
# daily PAY reached to API limit.
# daily PBL reached to API limit.
# daily PBT reached to API limit.
# daily PFR reached to API limit.
# daily PING reached to API limit.
# daily PINK reached to API limit.
# daily PIVX reached to API limit.
# daily PIX reached to API limit.
# daily PLBT reached to API limit.
# daily PLR reached to API limit.
# daily PLU reached to API limit.
# daily POA reached to API limit.
# daily POE reached to API limit.
# daily POLY <Response [200]>
# daily POSW reached to API limit.
# daily POT reached to API limit.
# daily POWR <Response [200]>
# daily PPC reached to API limit.
# daily PPT reached to API limit.
# daily PPY reached to API limit.
# daily PRG reached to API limit.
# daily PRL reached to API limit.
# daily PRO reached to API limit.
# daily PST reached to API limit.
# daily PTC reached to API limit.
# daily PTOY reached to API limit.
# daily PURA reached to API limit.
# daily QASH reached to API limit.
# daily QAU reached to API limit.
# daily QLC reached to API limit.
# daily QRK reached to API limit.
# daily QRL reached to API limit.
# daily QSP reached to API limit.
# daily QTL reached to API limit.
# daily QTUM <Response [200]>
# daily QUICK <Response [200]>
# daily QWARK reached to API limit.
# daily R reached to API limit.
# daily RADS reached to API limit.
# daily RAIN reached to API limit.
# daily RBIES reached to API limit.
# daily RBX reached to API limit.
# daily RBY reached to API limit.
# daily RCN reached to API limit.
# daily RDD reached to API limit.
# daily RDN reached to API limit.
# daily REC reached to API limit.
# daily RED reached to API limit.
# daily REP <Response [200]>
# daily REQ <Response [200]>
# daily RHOC reached to API limit.
# daily RIC reached to API limit.
# daily RISE reached to API limit.
# daily RLC <Response [200]>
# daily RLT reached to API limit.
# daily RPX reached to API limit.
# daily RRT reached to API limit.
# daily RUFF reached to API limit.
# daily RUNE <Response [200]>
# daily RUP reached to API limit.
# daily RVT reached to API limit.
# daily SAFEX reached to API limit.
# daily SALT reached to API limit.
# daily SAN reached to API limit.
# daily SBD reached to API limit.
# daily SBTC reached to API limit.
# daily SC <Response [200]>
# daily SEELE reached to API limit.
# daily SEQ reached to API limit.
# daily SHIB <Response [200]>
# daily SHIFT reached to API limit.
# daily SIB reached to API limit.
# daily SIGMA reached to API limit.
# daily SIGT reached to API limit.
# daily SJCX reached to API limit.
# daily SKIN reached to API limit.
# daily SKY reached to API limit.
# daily SLR reached to API limit.
# daily SLS reached to API limit.
# daily SMART reached to API limit.
# daily SMT reached to API limit.
# daily SNC reached to API limit.
# daily SNGLS reached to API limit.
# daily SNM reached to API limit.
# daily SNRG reached to API limit.
# daily SNT reached to API limit.
# daily SOC reached to API limit.
# daily SOL <Response [200]>
# daily SOUL reached to API limit.
# daily SPANK reached to API limit.
# daily SPC <Response [200]>
# daily SPHR reached to API limit.
# daily SPR reached to API limit.
# daily SNX <Response [200]>
# daily SRN reached to API limit.
# daily START reached to API limit.
# daily STEEM <Response [200]>
# daily STK reached to API limit.
# daily STORJ <Response [200]>
# daily STORM <Response [200]>
# daily STQ reached to API limit.
# daily STRAT <Response [200]>
# daily STX <Response [200]>
# daily SUB reached to API limit.
# daily SWFTC reached to API limit.
# daily SWIFT reached to API limit.
# daily SWT reached to API limit.
# daily SYNX reached to API limit.
# daily SYS <Response [200]>
# daily TAAS reached to API limit.
# daily TAU reached to API limit.
# daily TCC reached to API limit.
# daily TFL reached to API limit.
# daily THC reached to API limit.
# daily THETA <Response [200]>
# daily TIME reached to API limit.
# daily TIX reached to API limit.
# daily TKN reached to API limit.
# daily TKR reached to API limit.
# daily TKS reached to API limit.
# daily TNB reached to API limit.
# daily TNT reached to API limit.
# daily TOA reached to API limit.
# daily TRAC reached to API limit.
# daily TRC reached to API limit.
# daily TRCT reached to API limit.
# daily TRIBE <Response [200]>
# daily TRIG reached to API limit.
# daily TRST reached to API limit.
# daily TRUE reached to API limit.
# daily TRUST reached to API limit.
# daily TRX <Response [200]>
# daily TUSD <Response [200]>
# daily TX reached to API limit.
# daily UBQ reached to API limit.
# daily UKG reached to API limit.
# daily ULA reached to API limit.
# daily UNB reached to API limit.
# daily UNI <Response [200]>
# daily UNITY reached to API limit.
# daily UNO reached to API limit.
# daily UNY reached to API limit.
# daily UP reached to API limit.
# daily URO reached to API limit.
# daily USDT reached to API limit.
# daily UST <Response [200]>
# daily UTK <Response [200]>
# daily VEE reached to API limit.
# daily VEN <Response [200]>
# daily VERI reached to API limit.
# daily VET reached to API limit.
# daily VIA reached to API limit.
# daily VIB <Response [200]>
# daily VIBE reached to API limit.
# daily VIVO reached to API limit.
# daily VOISE reached to API limit.
# daily VOX reached to API limit.
# daily VPN reached to API limit.
# daily VRC reached to API limit.
# daily VRM reached to API limit.
# daily VRS reached to API limit.
# daily VSL reached to API limit.
# daily VTC reached to API limit.
# daily VTR reached to API limit.
# daily WABI reached to API limit.
# daily WAN <Response [200]>
# daily WAVES <Response [200]>
# daily WAX reached to API limit.
# daily WBTC <Response [200]>
# daily WCT reached to API limit.
# daily WDC reached to API limit.
# daily WGO reached to API limit.
# daily WGR reached to API limit.
# daily WINGS reached to API limit.
# daily WPR reached to API limit.
# daily WTC reached to API limit.
# daily WTT reached to API limit.
# daily XAS reached to API limit.
# daily XAUR reached to API limit.
# daily XBC reached to API limit.
# daily XBY reached to API limit.
# daily XCN reached to API limit.
# daily XCP reached to API limit.
# daily XDN reached to API limit.
# daily XEL reached to API limit.
# daily XEM <Response [200]>
# daily NEM reached to API limit.
# daily XHV reached to API limit.
# daily XID reached to API limit.
# daily XLM <Response [200]>
# daily XMG reached to API limit.
# daily XMR reached to API limit.
# daily XMT reached to API limit.
# daily XMY reached to API limit.
# daily XPM reached to API limit.
# daily XRL reached to API limit.
# daily XRP <Response [200]>
# daily XSPEC reached to API limit.
# daily XST reached to API limit.
# daily XTZ <Response [200]>
# daily XUC reached to API limit.
# daily XVC reached to API limit.
# daily XVG <Response [200]>
# daily XWC reached to API limit.
# daily XZC <Response [200]>
# daily XZR reached to API limit.
# daily YEE reached to API limit.
# daily YOYOW reached to API limit.
# daily ZCC reached to API limit.
# daily ZCL reached to API limit.
# daily ZCO reached to API limit.
# daily ZEC <Response [200]>
# daily ZEN <Response [200]>
# daily ZET reached to API limit.
# daily ZIL <Response [200]>
# daily ZLA reached to API limit.
# daily ZRX <Response [200]>
# weekly 1ST reached to API limit.
# weekly 2GIVE reached to API limit.
# weekly 808 reached to API limit.
# weekly AAVE <Response [200]>
# weekly ABT reached to API limit.
# weekly ABY reached to API limit.
# weekly AC reached to API limit.
# weekly ACT reached to API limit.
# weekly ADA <Response [200]>
# weekly ADT reached to API limit.
# weekly ADX <Response [200]>
# weekly AE reached to API limit.
# weekly AEON reached to API limit.
# weekly AGI reached to API limit.
# weekly AGRS reached to API limit.
# weekly AI reached to API limit.
# weekly AID reached to API limit.
# weekly AION <Response [200]>
# weekly AIR reached to API limit.
# weekly AKY reached to API limit.
# weekly ALGO <Response [200]>
# weekly ALIS reached to API limit.
# weekly AMBER reached to API limit.
# weekly AMP <Response [200]>
# weekly AMPL reached to API limit.
# weekly ANC <Response [200]>
# weekly ANT <Response [200]>
# weekly APPC reached to API limit.
# weekly APX reached to API limit.
# weekly ARDR <Response [200]>
# weekly ARK reached to API limit.
# weekly ARN reached to API limit.
# weekly AST reached to API limit.
# weekly ATB reached to API limit.
# weekly ATM <Response [200]>
# weekly ATOM <Response [200]>
# weekly ATS reached to API limit.
# weekly AUR reached to API limit.
# weekly AVAX <Response [200]>
# weekly AVT reached to API limit.
# weekly B3 reached to API limit.
# weekly BAND <Response [200]>
# weekly BAT <Response [200]>
# weekly BAY reached to API limit.
# weekly BBR reached to API limit.
# weekly BCAP reached to API limit.
# weekly BCC <Response [200]>
# weekly BCD reached to API limit.
# weekly BCH <Response [200]>
# weekly BCN reached to API limit.
# weekly BCPT reached to API limit.
# weekly BCX reached to API limit.
# weekly BCY reached to API limit.
# weekly BDL reached to API limit.
# weekly BEE reached to API limit.
# weekly BELA reached to API limit.
# weekly BET reached to API limit.
# weekly BFT reached to API limit.
# weekly BIS reached to API limit.
# weekly BITB reached to API limit.
# weekly BITBTC reached to API limit.
# weekly BITCNY reached to API limit.
# weekly BITEUR reached to API limit.
# weekly BITGOLD reached to API limit.
# weekly BITSILVER reached to API limit.
# weekly BITUSD reached to API limit.
# weekly BIX reached to API limit.
# weekly BLITZ reached to API limit.
# weekly BLK reached to API limit.
# weekly BLN reached to API limit.
# weekly BLOCK reached to API limit.
# weekly BLZ <Response [200]>
# weekly BMC reached to API limit.
# weekly BNB <Response [200]>
# weekly BNT <Response [200]>
# weekly BNTY reached to API limit.
# weekly BOST reached to API limit.
# weekly BOT reached to API limit.
# weekly BQ reached to API limit.
# weekly BRD reached to API limit.
# weekly BRK reached to API limit.
# weekly BRX reached to API limit.
# weekly BSV reached to API limit.
# weekly BTA reached to API limit.
# weekly BTC <Response [200]>
# weekly BTCB reached to API limit.
# weekly BTCD reached to API limit.
# weekly BTCP reached to API limit.
# weekly BTG <Response [200]>
# weekly BTM reached to API limit.
# weekly BTS <Response [200]>
# weekly BTSR reached to API limit.
# weekly BTT <Response [200]>
# weekly BTX reached to API limit.
# weekly BURST reached to API limit.
# weekly BUSD <Response [200]>
# weekly BUZZ reached to API limit.
# weekly BYC reached to API limit.
# weekly BYTOM reached to API limit.
# weekly C20 reached to API limit.
# weekly CAKE <Response [200]>
# weekly CANN reached to API limit.
# weekly CAT reached to API limit.
# weekly CCRB reached to API limit.
# weekly CDT reached to API limit.
# weekly CFI reached to API limit.
# weekly CHAT reached to API limit.
# weekly CHIPS reached to API limit.
# weekly CLAM reached to API limit.
# weekly CLOAK reached to API limit.
# weekly CMP reached to API limit.
# weekly CMT reached to API limit.
# weekly CND reached to API limit.
# weekly CNX reached to API limit.
# weekly COFI reached to API limit.
# weekly COMP <Response [200]>
# weekly COSS reached to API limit.
# weekly COVAL reached to API limit.
# weekly CRBIT reached to API limit.
# weekly CREA reached to API limit.
# weekly CREDO reached to API limit.
# weekly CRO reached to API limit.
# weekly CRW reached to API limit.
# weekly CSNO reached to API limit.
# weekly CTR reached to API limit.
# weekly CTXC <Response [200]>
# weekly CURE reached to API limit.
# weekly CVC <Response [200]>
# weekly DAI <Response [200]>
# weekly DAR <Response [200]>
# weekly DASH <Response [200]>
# weekly DATA <Response [200]>
# weekly DAY reached to API limit.
# weekly DBC reached to API limit.
# weekly DBIX reached to API limit.
# weekly DCN reached to API limit.
# weekly DCR <Response [200]>
# weekly DCT reached to API limit.
# weekly DDF reached to API limit.
# weekly DENT <Response [200]>
# weekly DFS reached to API limit.
# weekly DGB <Response [200]>
# weekly DGC reached to API limit.
# weekly DGD reached to API limit.
# weekly DICE reached to API limit.
# weekly DLT reached to API limit.
# weekly DMD reached to API limit.
# weekly DMT reached to API limit.
# weekly DNT <Response [200]>
# weekly DOGE <Response [200]>
# weekly DOPE reached to API limit.
# weekly DOT <Response [200]>
# weekly DRGN reached to API limit.
# weekly DTA reached to API limit.
# weekly DTB reached to API limit.
# weekly DYN reached to API limit.
# weekly EAC reached to API limit.
# weekly EBST reached to API limit.
# weekly EBTC reached to API limit.
# weekly ECC reached to API limit.
# weekly ECN reached to API limit.
# weekly EDG reached to API limit.
# weekly EDO reached to API limit.
# weekly EFL reached to API limit.
# weekly EGC reached to API limit.
# weekly EGLD <Response [200]>
# weekly EKT reached to API limit.
# weekly ELA reached to API limit.
# weekly ELEC reached to API limit.
# weekly ELF <Response [200]>
# weekly ELIX reached to API limit.
# weekly EMB reached to API limit.
# weekly EMC reached to API limit.
# weekly EMC2 reached to API limit.
# weekly ENG reached to API limit.
# weekly ENJ <Response [200]>
# weekly ENRG reached to API limit.
# weekly EOS <Response [200]>
# weekly EOT reached to API limit.
# weekly EQT reached to API limit.
# weekly ERC reached to API limit.
# weekly ETC <Response [200]>
# weekly ETH <Response [200]>
# weekly ETHD reached to API limit.
# weekly ETHOS reached to API limit.
# weekly ETN reached to API limit.
# weekly ETP reached to API limit.
# weekly ETT reached to API limit.
# weekly EVE reached to API limit.
# weekly EVX reached to API limit.
# weekly EXCL reached to API limit.
# weekly EXP reached to API limit.
# weekly FCT reached to API limit.
# weekly FIL <Response [200]>
# weekly FLDC reached to API limit.
# weekly FLO reached to API limit.
# weekly FLT reached to API limit.
# weekly FRST reached to API limit.
# weekly FTC reached to API limit.
# weekly FTT <Response [200]>
# weekly FUEL reached to API limit.
# weekly FUN <Response [200]>
# weekly GAM reached to API limit.
# weekly GAME reached to API limit.
# weekly GAS <Response [200]>
# weekly GBG reached to API limit.
# weekly GBX reached to API limit.
# weekly GBYTE reached to API limit.
# weekly GCR reached to API limit.
# weekly GEO reached to API limit.
# weekly GLD reached to API limit.
# weekly GNO <Response [200]>
# weekly GNT reached to API limit.
# weekly GOLOS reached to API limit.
# weekly GRC reached to API limit.
# weekly GRT <Response [200]>
# weekly GRS reached to API limit.
# weekly GRWI reached to API limit.
# weekly GTC <Response [200]>
# weekly GTO <Response [200]>
# weekly GUP reached to API limit.
# weekly GVT reached to API limit.
# weekly GXS <Response [200]>
# weekly HBAR reached to API limit.
# weekly HBN reached to API limit.
# weekly HEAT reached to API limit.
# weekly HMQ reached to API limit.
# weekly HPB reached to API limit.
# weekly HSR reached to API limit.
# weekly HT reached to API limit.
# weekly HUSH reached to API limit.
# weekly HVN reached to API limit.
# weekly HXX reached to API limit.
# weekly ICN reached to API limit.
# weekly ICX <Response [200]>
# weekly IFC reached to API limit.
# weekly IFT reached to API limit.
# weekly IGNIS reached to API limit.
# weekly INCNT reached to API limit.
# weekly IND reached to API limit.
# weekly INF reached to API limit.
# weekly INK reached to API limit.
# weekly INS reached to API limit.
# weekly INSTAR reached to API limit.
# weekly INT reached to API limit.
# weekly INXT reached to API limit.
# weekly IOC reached to API limit.
# weekly ION reached to API limit.
# weekly IOP reached to API limit.
# weekly IOST <Response [200]>
# weekly IOTA <Response [200]>
# weekly IOTX <Response [200]>
# weekly IQT reached to API limit.
# weekly ITC reached to API limit.
# weekly IXC reached to API limit.
# weekly IXT reached to API limit.
# weekly J8T reached to API limit.
# weekly JNT reached to API limit.
# weekly KCS reached to API limit.
# weekly KICK reached to API limit.
# weekly KIN reached to API limit.
# weekly KLAY reached to API limit.
# weekly KMD <Response [200]>
# weekly KNC <Response [200]>
# weekly KORE reached to API limit.
# weekly KSM <Response [200]>
# weekly LBC reached to API limit.
# weekly LCC reached to API limit.
# weekly LEND <Response [200]>
# weekly LEO reached to API limit.
# weekly LEV reached to API limit.
# weekly LGD reached to API limit.
# weekly LINDA reached to API limit.
# weekly LINK <Response [200]>
# weekly LKK reached to API limit.
# weekly LMC reached to API limit.
# weekly LOCI reached to API limit.
# weekly LOOM <Response [200]>
# weekly LRC <Response [200]>
# weekly LSK <Response [200]>
# weekly LTC <Response [200]>
# weekly LUN reached to API limit.
# weekly LUNA <Response [200]>
# weekly MAID reached to API limit.
# weekly MANA <Response [200]>
# weekly MATIC <Response [200]>
# weekly MAX reached to API limit.
# weekly MBRS reached to API limit.
# weekly MCAP reached to API limit.
# weekly MCO <Response [200]>
# weekly MDA reached to API limit.
# weekly MEC reached to API limit.
# weekly MED reached to API limit.
# weekly MEME reached to API limit.
# weekly MER reached to API limit.
# weekly MGC reached to API limit.
# weekly MGO reached to API limit.
# weekly MINEX reached to API limit.
# weekly MINT reached to API limit.
# weekly MIOTA reached to API limit.
# weekly MITH <Response [200]>
# weekly MKR <Response [200]>
# weekly MLN <Response [200]>
# weekly MNE reached to API limit.
# weekly MNX reached to API limit.
# weekly MOD reached to API limit.
# weekly MONA reached to API limit.
# weekly MRT reached to API limit.
# weekly MSP reached to API limit.
# weekly MTH reached to API limit.
# weekly MTN reached to API limit.
# weekly MUE reached to API limit.
# weekly MUSIC reached to API limit.
# weekly MYB reached to API limit.
# weekly MYST reached to API limit.
# weekly MZC reached to API limit.
# weekly NAMO reached to API limit.
# weekly NANO <Response [200]>
# weekly NAS reached to API limit.
# weekly NAV reached to API limit.
# weekly NBT <Response [200]>
# weekly NCASH reached to API limit.
# weekly NDC reached to API limit.
# weekly NEBL <Response [200]>
# weekly NEO <Response [200]>
# weekly NEOS reached to API limit.
# weekly NET reached to API limit.
# weekly NLC2 reached to API limit.
# weekly NLG reached to API limit.
# weekly NMC reached to API limit.
# weekly NMR <Response [200]>
# weekly NOBL reached to API limit.
# weekly NOTE reached to API limit.
# weekly NPXS <Response [200]>
# weekly NSR reached to API limit.
# weekly NTO reached to API limit.
# weekly NULS <Response [200]>
# weekly NVC reached to API limit.
# weekly NXC reached to API limit.
# weekly NXS reached to API limit.
# weekly NXT reached to API limit.
# weekly OAX <Response [200]>
# weekly OBITS reached to API limit.
# weekly OCL reached to API limit.
# weekly OCN reached to API limit.
# weekly ODEM reached to API limit.
# weekly ODN reached to API limit.
# weekly OF reached to API limit.
# weekly OK reached to API limit.
# weekly OMG <Response [200]>
# weekly OMNI reached to API limit.
# weekly ONION reached to API limit.
# weekly ONT <Response [200]>
# weekly OPT reached to API limit.
# weekly ORN <Response [200]>
# weekly OST reached to API limit.
# weekly PART reached to API limit.
# weekly PASC reached to API limit.
# weekly PAY reached to API limit.
# weekly PBL reached to API limit.
# weekly PBT reached to API limit.
# weekly PFR reached to API limit.
# weekly PING reached to API limit.
# weekly PINK reached to API limit.
# weekly PIVX reached to API limit.
# weekly PIX reached to API limit.
# weekly PLBT reached to API limit.
# weekly PLR reached to API limit.
# weekly PLU reached to API limit.
# weekly POA reached to API limit.
# weekly POE reached to API limit.
# weekly POLY <Response [200]>
# weekly POSW reached to API limit.
# weekly POT reached to API limit.
# weekly POWR <Response [200]>
# weekly PPC reached to API limit.
# weekly PPT reached to API limit.
# weekly PPY reached to API limit.
# weekly PRG reached to API limit.
# weekly PRL reached to API limit.
# weekly PRO reached to API limit.
# weekly PST reached to API limit.
# weekly PTC reached to API limit.
# weekly PTOY reached to API limit.
# weekly PURA reached to API limit.
# weekly QASH reached to API limit.
# weekly QAU reached to API limit.
# weekly QLC reached to API limit.
# weekly QRK reached to API limit.
# weekly QRL reached to API limit.
# weekly QSP reached to API limit.
# weekly QTL reached to API limit.
# weekly QTUM <Response [200]>
# weekly QUICK <Response [200]>
# weekly QWARK reached to API limit.
# weekly R reached to API limit.
# weekly RADS reached to API limit.
# weekly RAIN reached to API limit.
# weekly RBIES reached to API limit.
# weekly RBX reached to API limit.
# weekly RBY reached to API limit.
# weekly RCN reached to API limit.
# weekly RDD reached to API limit.
# weekly RDN reached to API limit.
# weekly REC reached to API limit.
# weekly RED reached to API limit.
# weekly REP <Response [200]>
# weekly REQ <Response [200]>
# weekly RHOC reached to API limit.
# weekly RIC reached to API limit.
# weekly RISE reached to API limit.
# weekly RLC <Response [200]>
# weekly RLT reached to API limit.
# weekly RPX reached to API limit.
# weekly RRT reached to API limit.
# weekly RUFF reached to API limit.
# weekly RUNE <Response [200]>
# weekly RUP reached to API limit.
# weekly RVT reached to API limit.
# weekly SAFEX reached to API limit.
# weekly SALT reached to API limit.
# weekly SAN reached to API limit.
# weekly SBD reached to API limit.
# weekly SBTC reached to API limit.
# weekly SC <Response [200]>
# weekly SEELE reached to API limit.
# weekly SEQ reached to API limit.
# weekly SHIB <Response [200]>
# weekly SHIFT reached to API limit.
# weekly SIB reached to API limit.
# weekly SIGMA reached to API limit.
# weekly SIGT reached to API limit.
# weekly SJCX reached to API limit.
# weekly SKIN reached to API limit.
# weekly SKY reached to API limit.
# weekly SLR reached to API limit.
# weekly SLS reached to API limit.
# weekly SMART reached to API limit.
# weekly SMT reached to API limit.
# weekly SNC reached to API limit.
# weekly SNGLS reached to API limit.
# weekly SNM reached to API limit.
# weekly SNRG reached to API limit.
# weekly SNT reached to API limit.
# weekly SOC reached to API limit.
# weekly SOL <Response [200]>
# weekly SOUL reached to API limit.
# weekly SPANK reached to API limit.
# weekly SPC <Response [200]>
# weekly SPHR reached to API limit.
# weekly SPR reached to API limit.
# weekly SNX <Response [200]>
# weekly SRN reached to API limit.
# weekly START reached to API limit.
# weekly STEEM <Response [200]>
# weekly STK reached to API limit.
# weekly STORJ <Response [200]>
# weekly STORM <Response [200]>
# weekly STQ reached to API limit.
# weekly STRAT <Response [200]>
# weekly STX <Response [200]>
# weekly SUB reached to API limit.
# weekly SWFTC reached to API limit.
# weekly SWIFT reached to API limit.
# weekly SWT reached to API limit.
# weekly SYNX reached to API limit.
# weekly SYS <Response [200]>
# weekly TAAS reached to API limit.
# weekly TAU reached to API limit.
# weekly TCC reached to API limit.
# weekly TFL reached to API limit.
# weekly THC reached to API limit.
# weekly THETA <Response [200]>
# weekly TIME reached to API limit.
# weekly TIX reached to API limit.
# weekly TKN reached to API limit.
# weekly TKR reached to API limit.
# weekly TKS reached to API limit.
# weekly TNB reached to API limit.
# weekly TNT reached to API limit.
# weekly TOA reached to API limit.
# weekly TRAC reached to API limit.
# weekly TRC reached to API limit.
# weekly TRCT reached to API limit.
# weekly TRIBE <Response [200]>
# weekly TRIG reached to API limit.
# weekly TRST reached to API limit.
# weekly TRUE reached to API limit.
# weekly TRUST reached to API limit.
# weekly TRX <Response [200]>
# weekly TUSD <Response [200]>
# weekly TX reached to API limit.
# weekly UBQ reached to API limit.
# weekly UKG reached to API limit.
# weekly ULA reached to API limit.
# weekly UNB reached to API limit.
# weekly UNI <Response [200]>
# weekly UNITY reached to API limit.
# weekly UNO reached to API limit.
# weekly UNY reached to API limit.
# weekly UP reached to API limit.
# weekly URO reached to API limit.
# weekly USDT reached to API limit.
# weekly UST <Response [200]>
# weekly UTK <Response [200]>
# weekly VEE reached to API limit.
# weekly VEN <Response [200]>
# weekly VERI reached to API limit.
# weekly VET reached to API limit.
# weekly VIA reached to API limit.
# weekly VIB <Response [200]>
# weekly VIBE reached to API limit.
# weekly VIVO reached to API limit.
# weekly VOISE reached to API limit.
# weekly VOX reached to API limit.
# weekly VPN reached to API limit.
# weekly VRC reached to API limit.
# weekly VRM reached to API limit.
# weekly VRS reached to API limit.
# weekly VSL reached to API limit.
# weekly VTC reached to API limit.
# weekly VTR reached to API limit.
# weekly WABI reached to API limit.
# weekly WAN <Response [200]>
# weekly WAVES <Response [200]>
# weekly WAX reached to API limit.
# weekly WBTC <Response [200]>
# weekly WCT reached to API limit.
# weekly WDC reached to API limit.
# weekly WGO reached to API limit.
# weekly WGR reached to API limit.
# weekly WINGS reached to API limit.
# weekly WPR reached to API limit.
# weekly WTC reached to API limit.
# weekly WTT reached to API limit.
# weekly XAS reached to API limit.
# weekly XAUR reached to API limit.
# weekly XBC reached to API limit.
# weekly XBY reached to API limit.
# weekly XCN reached to API limit.
# weekly XCP reached to API limit.
# weekly XDN reached to API limit.
# weekly XEL reached to API limit.
# weekly XEM <Response [200]>
# weekly NEM reached to API limit.
# weekly XHV reached to API limit.
# weekly XID reached to API limit.
# weekly XLM <Response [200]>
# weekly XMG reached to API limit.
# weekly XMR reached to API limit.
# weekly XMT reached to API limit.
# weekly XMY reached to API limit.
# weekly XPM reached to API limit.
# weekly XRL reached to API limit.
# weekly XRP <Response [200]>
# weekly XSPEC reached to API limit.
# weekly XST reached to API limit.
# weekly XTZ <Response [200]>
# weekly XUC reached to API limit.
# weekly XVC reached to API limit.
# weekly XVG <Response [200]>
# weekly XWC reached to API limit.
# weekly XZC <Response [200]>
# weekly XZR reached to API limit.
# weekly YEE reached to API limit.
# weekly YOYOW reached to API limit.
# weekly ZCC reached to API limit.
# weekly ZCL reached to API limit.
# weekly ZCO reached to API limit.
# weekly ZEC <Response [200]>
# weekly ZEN <Response [200]>
# weekly ZET reached to API limit.
# weekly ZIL <Response [200]>
# weekly ZLA reached to API limit.
# weekly ZRX <Response [200]>
# monthly 1ST reached to API limit.
# monthly 2GIVE reached to API limit.
# monthly 808 reached to API limit.
# monthly AAVE <Response [200]>
# monthly ABT reached to API limit.
# monthly ABY reached to API limit.
# monthly AC reached to API limit.
# monthly ACT reached to API limit.
# monthly ADA <Response [200]>
# monthly ADT reached to API limit.
# monthly ADX <Response [200]>
# monthly AE reached to API limit.
# monthly AEON reached to API limit.
# monthly AGI reached to API limit.
# monthly AGRS reached to API limit.
# monthly AI reached to API limit.
# monthly AID reached to API limit.
# monthly AION <Response [200]>
# monthly AIR reached to API limit.
# monthly AKY reached to API limit.
# monthly ALGO <Response [200]>
# monthly ALIS reached to API limit.
# monthly AMBER reached to API limit.
# monthly AMP <Response [200]>
# monthly AMPL reached to API limit.
# monthly ANC <Response [200]>
# monthly ANT <Response [200]>
# monthly APPC reached to API limit.
# monthly APX reached to API limit.
# monthly ARDR <Response [200]>
# monthly ARK reached to API limit.
# monthly ARN reached to API limit.
# monthly AST reached to API limit.
# monthly ATB reached to API limit.
# monthly ATM <Response [200]>
# monthly ATOM <Response [200]>
# monthly ATS reached to API limit.
# monthly AUR reached to API limit.
# monthly AVAX <Response [200]>
# monthly AVT reached to API limit.
# monthly B3 reached to API limit.
# monthly BAND <Response [200]>
# monthly BAT <Response [200]>
# monthly BAY reached to API limit.
# monthly BBR reached to API limit.
# monthly BCAP reached to API limit.
# monthly BCC <Response [200]>
# monthly BCD reached to API limit.
# monthly BCH <Response [200]>
# monthly BCN reached to API limit.
# monthly BCPT reached to API limit.
# monthly BCX reached to API limit.
# monthly BCY reached to API limit.
# monthly BDL reached to API limit.
# monthly BEE reached to API limit.
# monthly BELA reached to API limit.
# monthly BET reached to API limit.
# monthly BFT reached to API limit.
# monthly BIS reached to API limit.
# monthly BITB reached to API limit.
# monthly BITBTC reached to API limit.
# monthly BITCNY reached to API limit.
# monthly BITEUR reached to API limit.
# monthly BITGOLD reached to API limit.
# monthly BITSILVER reached to API limit.
# monthly BITUSD reached to API limit.
# monthly BIX reached to API limit.
# monthly BLITZ reached to API limit.
# monthly BLK reached to API limit.
# monthly BLN reached to API limit.
# monthly BLOCK reached to API limit.
# monthly BLZ <Response [200]>
# monthly BMC reached to API limit.
# monthly BNB <Response [200]>
# monthly BNT <Response [200]>
# monthly BNTY reached to API limit.
# monthly BOST reached to API limit.
# monthly BOT reached to API limit.
# monthly BQ reached to API limit.
# monthly BRD reached to API limit.
# monthly BRK reached to API limit.
# monthly BRX reached to API limit.
# monthly BSV reached to API limit.
# monthly BTA reached to API limit.
# monthly BTC <Response [200]>
# monthly BTCB reached to API limit.
# monthly BTCD reached to API limit.
# monthly BTCP reached to API limit.
# monthly BTG <Response [200]>
# monthly BTM reached to API limit.
# monthly BTS <Response [200]>
# monthly BTSR reached to API limit.
# monthly BTT <Response [200]>
# monthly BTX reached to API limit.
# monthly BURST reached to API limit.
# monthly BUSD <Response [200]>
# monthly BUZZ reached to API limit.
# monthly BYC reached to API limit.
# monthly BYTOM reached to API limit.
# monthly C20 reached to API limit.
# monthly CAKE <Response [200]>
# monthly CANN reached to API limit.
# monthly CAT reached to API limit.
# monthly CCRB reached to API limit.
# monthly CDT reached to API limit.
# monthly CFI reached to API limit.
# monthly CHAT reached to API limit.
# monthly CHIPS reached to API limit.
# monthly CLAM reached to API limit.
# monthly CLOAK reached to API limit.
# monthly CMP reached to API limit.
# monthly CMT reached to API limit.
# monthly CND reached to API limit.
# monthly CNX reached to API limit.
# monthly COFI reached to API limit.
# monthly COMP <Response [200]>
# monthly COSS reached to API limit.
# monthly COVAL reached to API limit.
# monthly CRBIT reached to API limit.
# monthly CREA reached to API limit.
# monthly CREDO reached to API limit.
# monthly CRO reached to API limit.
# monthly CRW reached to API limit.
# monthly CSNO reached to API limit.
# monthly CTR reached to API limit.
# monthly CTXC <Response [200]>
# monthly CURE reached to API limit.
# monthly CVC <Response [200]>
# monthly DAI <Response [200]>
# monthly DAR <Response [200]>
# monthly DASH <Response [200]>
# monthly DATA <Response [200]>
# monthly DAY reached to API limit.
# monthly DBC reached to API limit.
# monthly DBIX reached to API limit.
# monthly DCN reached to API limit.
# monthly DCR <Response [200]>
# monthly DCT reached to API limit.
# monthly DDF reached to API limit.
# monthly DENT <Response [200]>
# monthly DFS reached to API limit.
# monthly DGB <Response [200]>
# monthly DGC reached to API limit.
# monthly DGD reached to API limit.
# monthly DICE reached to API limit.
# monthly DLT reached to API limit.
# monthly DMD reached to API limit.
# monthly DMT reached to API limit.
# monthly DNT <Response [200]>
# monthly DOGE <Response [200]>
# monthly DOPE reached to API limit.
# monthly DOT <Response [200]>
# monthly DRGN reached to API limit.
# monthly DTA reached to API limit.
# monthly DTB reached to API limit.
# monthly DYN reached to API limit.
# monthly EAC reached to API limit.
# monthly EBST reached to API limit.
# monthly EBTC reached to API limit.
# monthly ECC reached to API limit.
# monthly ECN reached to API limit.
# monthly EDG reached to API limit.
# monthly EDO reached to API limit.
# monthly EFL reached to API limit.
# monthly EGC reached to API limit.
# monthly EGLD <Response [200]>
# monthly EKT reached to API limit.
# monthly ELA reached to API limit.
# monthly ELEC reached to API limit.
# monthly ELF <Response [200]>
# monthly ELIX reached to API limit.
# monthly EMB reached to API limit.
# monthly EMC reached to API limit.
# monthly EMC2 reached to API limit.
# monthly ENG reached to API limit.
# monthly ENJ <Response [200]>
# monthly ENRG reached to API limit.
# monthly EOS <Response [200]>
# monthly EOT reached to API limit.
# monthly EQT reached to API limit.
# monthly ERC reached to API limit.
# monthly ETC <Response [200]>
# monthly ETH <Response [200]>
# monthly ETHD reached to API limit.
# monthly ETHOS reached to API limit.
# monthly ETN reached to API limit.
# monthly ETP reached to API limit.
# monthly ETT reached to API limit.
# monthly EVE reached to API limit.
# monthly EVX reached to API limit.
# monthly EXCL reached to API limit.
# monthly EXP reached to API limit.
# monthly FCT reached to API limit.
# monthly FIL <Response [200]>
# monthly FLDC reached to API limit.
# monthly FLO reached to API limit.
# monthly FLT reached to API limit.
# monthly FRST reached to API limit.
# monthly FTC reached to API limit.
# monthly FTT <Response [200]>
# monthly FUEL reached to API limit.
# monthly FUN <Response [200]>
# monthly GAM reached to API limit.
# monthly GAME reached to API limit.
# monthly GAS <Response [200]>
# monthly GBG reached to API limit.
# monthly GBX reached to API limit.
# monthly GBYTE reached to API limit.
# monthly GCR reached to API limit.
# monthly GEO reached to API limit.
# monthly GLD reached to API limit.
# monthly GNO <Response [200]>
# monthly GNT reached to API limit.
# monthly GOLOS reached to API limit.
# monthly GRC reached to API limit.
# monthly GRT <Response [200]>
# monthly GRS reached to API limit.
# monthly GRWI reached to API limit.
# monthly GTC <Response [200]>
# monthly GTO <Response [200]>
# monthly GUP reached to API limit.
# monthly GVT reached to API limit.
# monthly GXS <Response [200]>
# monthly HBAR reached to API limit.
# monthly HBN reached to API limit.
# monthly HEAT reached to API limit.
# monthly HMQ reached to API limit.
# monthly HPB reached to API limit.
# monthly HSR reached to API limit.
# monthly HT reached to API limit.
# monthly HUSH reached to API limit.
# monthly HVN reached to API limit.
# monthly HXX reached to API limit.
# monthly ICN reached to API limit.
# monthly ICX <Response [200]>
# monthly IFC reached to API limit.
# monthly IFT reached to API limit.
# monthly IGNIS reached to API limit.
# monthly INCNT reached to API limit.
# monthly IND reached to API limit.
# monthly INF reached to API limit.
# monthly INK reached to API limit.
# monthly INS reached to API limit.
# monthly INSTAR reached to API limit.
# monthly INT reached to API limit.
# monthly INXT reached to API limit.
# monthly IOC reached to API limit.
# monthly ION reached to API limit.
# monthly IOP reached to API limit.
# monthly IOST <Response [200]>
# monthly IOTA <Response [200]>
# monthly IOTX <Response [200]>
# monthly IQT reached to API limit.
# monthly ITC reached to API limit.
# monthly IXC reached to API limit.
# monthly IXT reached to API limit.
# monthly J8T reached to API limit.
# monthly JNT reached to API limit.
# monthly KCS reached to API limit.
# monthly KICK reached to API limit.
# monthly KIN reached to API limit.
# monthly KLAY reached to API limit.
# monthly KMD <Response [200]>
# monthly KNC <Response [200]>
# monthly KORE reached to API limit.
# monthly KSM <Response [200]>
# monthly LBC reached to API limit.
# monthly LCC reached to API limit.
# monthly LEND <Response [200]>
# monthly LEO reached to API limit.
# monthly LEV reached to API limit.
# monthly LGD reached to API limit.
# monthly LINDA reached to API limit.
# monthly LINK <Response [200]>
# monthly LKK reached to API limit.
# monthly LMC reached to API limit.
# monthly LOCI reached to API limit.
# monthly LOOM <Response [200]>
# monthly LRC <Response [200]>
# monthly LSK <Response [200]>
# monthly LTC <Response [200]>
# monthly LUN reached to API limit.
# monthly LUNA <Response [200]>
# monthly MAID reached to API limit.
# monthly MANA <Response [200]>
# monthly MATIC <Response [200]>
# monthly MAX reached to API limit.
# monthly MBRS reached to API limit.
# monthly MCAP reached to API limit.
# monthly MCO <Response [200]>
# monthly MDA reached to API limit.
# monthly MEC reached to API limit.
# monthly MED reached to API limit.
# monthly MEME reached to API limit.
# monthly MER reached to API limit.
# monthly MGC reached to API limit.
# monthly MGO reached to API limit.
# monthly MINEX reached to API limit.
# monthly MINT reached to API limit.
# monthly MIOTA reached to API limit.
# monthly MITH <Response [200]>
# monthly MKR <Response [200]>
# monthly MLN <Response [200]>
# monthly MNE reached to API limit.
# monthly MNX reached to API limit.
# monthly MOD reached to API limit.
# monthly MONA reached to API limit.
# monthly MRT reached to API limit.
# monthly MSP reached to API limit.
# monthly MTH reached to API limit.
# monthly MTN reached to API limit.
# monthly MUE reached to API limit.
# monthly MUSIC reached to API limit.
# monthly MYB reached to API limit.
# monthly MYST reached to API limit.
# monthly MZC reached to API limit.
# monthly NAMO reached to API limit.
# monthly NANO <Response [200]>
# monthly NAS reached to API limit.
# monthly NAV reached to API limit.
# monthly NBT <Response [200]>
# monthly NCASH reached to API limit.
# monthly NDC reached to API limit.
# monthly NEBL <Response [200]>
# monthly NEO <Response [200]>
# monthly NEOS reached to API limit.
# monthly NET reached to API limit.
# monthly NLC2 reached to API limit.
# monthly NLG reached to API limit.
# monthly NMC reached to API limit.
# monthly NMR <Response [200]>
# monthly NOBL reached to API limit.
# monthly NOTE reached to API limit.
# monthly NPXS <Response [200]>
# monthly NSR reached to API limit.
# monthly NTO reached to API limit.
# monthly NULS <Response [200]>
# monthly NVC reached to API limit.
# monthly NXC reached to API limit.
# monthly NXS reached to API limit.
# monthly NXT reached to API limit.
# monthly OAX <Response [200]>
# monthly OBITS reached to API limit.
# monthly OCL reached to API limit.
# monthly OCN reached to API limit.
# monthly ODEM reached to API limit.
# monthly ODN reached to API limit.
# monthly OF reached to API limit.
# monthly OK reached to API limit.
# monthly OMG <Response [200]>
# monthly OMNI reached to API limit.
# monthly ONION reached to API limit.
# monthly ONT <Response [200]>
# monthly OPT reached to API limit.
# monthly ORN <Response [200]>
# monthly OST reached to API limit.
# monthly PART reached to API limit.
# monthly PASC reached to API limit.
# monthly PAY reached to API limit.
# monthly PBL reached to API limit.
# monthly PBT reached to API limit.
# monthly PFR reached to API limit.
# monthly PING reached to API limit.
# monthly PINK reached to API limit.
# monthly PIVX reached to API limit.
# monthly PIX reached to API limit.
# monthly PLBT reached to API limit.
# monthly PLR reached to API limit.
# monthly PLU reached to API limit.
# monthly POA reached to API limit.
# monthly POE reached to API limit.
# monthly POLY <Response [200]>
# monthly POSW reached to API limit.
# monthly POT reached to API limit.
# monthly POWR <Response [200]>
# monthly PPC reached to API limit.
# monthly PPT reached to API limit.
# monthly PPY reached to API limit.
# monthly PRG reached to API limit.
# monthly PRL reached to API limit.
# monthly PRO reached to API limit.
# monthly PST reached to API limit.
# monthly PTC reached to API limit.
# monthly PTOY reached to API limit.
# monthly PURA reached to API limit.
# monthly QASH reached to API limit.
# monthly QAU reached to API limit.
# monthly QLC reached to API limit.
# monthly QRK reached to API limit.
# monthly QRL reached to API limit.
# monthly QSP reached to API limit.
# monthly QTL reached to API limit.
# monthly QTUM <Response [200]>
# monthly QUICK <Response [200]>
# monthly QWARK reached to API limit.
# monthly R reached to API limit.
# monthly RADS reached to API limit.
# monthly RAIN reached to API limit.
# monthly RBIES reached to API limit.
# monthly RBX reached to API limit.
# monthly RBY reached to API limit.
# monthly RCN reached to API limit.
# monthly RDD reached to API limit.
# monthly RDN reached to API limit.
# monthly REC reached to API limit.
# monthly RED reached to API limit.
# monthly REP <Response [200]>
# monthly REQ <Response [200]>
# monthly RHOC reached to API limit.
# monthly RIC reached to API limit.
# monthly RISE reached to API limit.
# monthly RLC <Response [200]>
# monthly RLT reached to API limit.
# monthly RPX reached to API limit.
# monthly RRT reached to API limit.
# monthly RUFF reached to API limit.
# monthly RUNE <Response [200]>
# monthly RUP reached to API limit.
# monthly RVT reached to API limit.
# monthly SAFEX reached to API limit.
# monthly SALT reached to API limit.
# monthly SAN reached to API limit.
# monthly SBD reached to API limit.
# monthly SBTC reached to API limit.
# monthly SC <Response [200]>
# monthly SEELE reached to API limit.
# monthly SEQ reached to API limit.
# monthly SHIB <Response [200]>
# monthly SHIFT reached to API limit.
# monthly SIB reached to API limit.
# monthly SIGMA reached to API limit.
# monthly SIGT reached to API limit.
# monthly SJCX reached to API limit.
# monthly SKIN reached to API limit.
# monthly SKY reached to API limit.
# monthly SLR reached to API limit.
# monthly SLS reached to API limit.
# monthly SMART reached to API limit.
# monthly SMT reached to API limit.
# monthly SNC reached to API limit.
# monthly SNGLS reached to API limit.
# monthly SNM reached to API limit.
# monthly SNRG reached to API limit.
# monthly SNT reached to API limit.
# monthly SOC reached to API limit.
# monthly SOL <Response [200]>
# monthly SOUL reached to API limit.
# monthly SPANK reached to API limit.
# monthly SPC <Response [200]>
# monthly SPHR reached to API limit.
# monthly SPR reached to API limit.
# monthly SNX <Response [200]>
# monthly SRN reached to API limit.
# monthly START reached to API limit.
# monthly STEEM <Response [200]>
# monthly STK reached to API limit.
# monthly STORJ <Response [200]>
# monthly STORM <Response [200]>
# monthly STQ reached to API limit.
# monthly STRAT <Response [200]>
# monthly STX <Response [200]>
# monthly SUB reached to API limit.
# monthly SWFTC reached to API limit.
# monthly SWIFT reached to API limit.
# monthly SWT reached to API limit.
# monthly SYNX reached to API limit.
# monthly SYS <Response [200]>
# monthly TAAS reached to API limit.
# monthly TAU reached to API limit.
# monthly TCC reached to API limit.
# monthly TFL reached to API limit.
# monthly THC reached to API limit.
# monthly THETA <Response [200]>
# monthly TIME reached to API limit.
# monthly TIX reached to API limit.
# monthly TKN reached to API limit.
# monthly TKR reached to API limit.
# monthly TKS reached to API limit.
# monthly TNB reached to API limit.
# monthly TNT reached to API limit.
# monthly TOA reached to API limit.
# monthly TRAC reached to API limit.
# monthly TRC reached to API limit.
# monthly TRCT reached to API limit.
# monthly TRIBE <Response [200]>
# monthly TRIG reached to API limit.
# monthly TRST reached to API limit.
# monthly TRUE reached to API limit.
# monthly TRUST reached to API limit.
# monthly TRX <Response [200]>
# monthly TUSD <Response [200]>
# monthly TX reached to API limit.
# monthly UBQ reached to API limit.
# monthly UKG reached to API limit.
# monthly ULA reached to API limit.
# monthly UNB reached to API limit.
# monthly UNI <Response [200]>
# monthly UNITY reached to API limit.
# monthly UNO reached to API limit.
# monthly UNY reached to API limit.
# monthly UP reached to API limit.
# monthly URO reached to API limit.
# monthly USDT reached to API limit.
# monthly UST <Response [200]>
# monthly UTK <Response [200]>
# monthly VEE reached to API limit.
# monthly VEN <Response [200]>
# monthly VERI reached to API limit.
# monthly VET reached to API limit.
# monthly VIA reached to API limit.
# monthly VIB <Response [200]>
# monthly VIBE reached to API limit.
# monthly VIVO reached to API limit.
# monthly VOISE reached to API limit.
# monthly VOX reached to API limit.
# monthly VPN reached to API limit.
# monthly VRC reached to API limit.
# monthly VRM reached to API limit.
# monthly VRS reached to API limit.
# monthly VSL reached to API limit.
# monthly VTC reached to API limit.
# monthly VTR reached to API limit.
# monthly WABI reached to API limit.
# monthly WAN <Response [200]>
# monthly WAVES <Response [200]>
# monthly WAX reached to API limit.
# monthly WBTC <Response [200]>
# monthly WCT reached to API limit.
# monthly WDC reached to API limit.
# monthly WGO reached to API limit.
# monthly WGR reached to API limit.
# monthly WINGS reached to API limit.
# monthly WPR reached to API limit.
# monthly WTC reached to API limit.
# monthly WTT reached to API limit.
# monthly XAS reached to API limit.
# monthly XAUR reached to API limit.
# monthly XBC reached to API limit.
# monthly XBY reached to API limit.
# monthly XCN reached to API limit.
# monthly XCP reached to API limit.
# monthly XDN reached to API limit.
# monthly XEL reached to API limit.
# monthly XEM <Response [200]>
# monthly NEM reached to API limit.
# monthly XHV reached to API limit.
# monthly XID reached to API limit.
# monthly XLM <Response [200]>
# monthly XMG reached to API limit.
# monthly XMR reached to API limit.
# monthly XMT reached to API limit.
# monthly XMY reached to API limit.
# monthly XPM reached to API limit.
# monthly XRL reached to API limit.
# monthly XRP <Response [200]>
# monthly XSPEC reached to API limit.
# monthly XST reached to API limit.
# monthly XTZ <Response [200]>
# monthly XUC reached to API limit.
# monthly XVC reached to API limit.
# monthly XVG <Response [200]>
# monthly XWC reached to API limit.
# monthly XZC <Response [200]>
# monthly XZR reached to API limit.
# monthly YEE reached to API limit.
# monthly YOYOW reached to API limit.
# monthly ZCC reached to API limit.
# monthly ZCL reached to API limit.
# monthly ZCO reached to API limit.
# monthly ZEC <Response [200]>
# monthly ZEN <Response [200]>
# monthly ZET reached to API limit.
# monthly ZIL <Response [200]>
# monthly ZLA reached to API limit.
# monthly ZRX <Response [200]>
#          timestamp  open (USD)  high (USD)  low (USD)  close (USD)  \
# 0       2023-05-08     68.7000     69.2000    68.2000      69.0000
# 1       2023-05-07     69.7000     70.2000    68.2000      68.7000
# 2       2023-05-06     73.4000     74.1000    68.5000      69.8000
# 3       2023-05-05     70.8000     74.3000    70.0000      73.5000
# 4       2023-05-04     71.8000     72.1000    70.2000      70.8000
# ...            ...         ...         ...        ...          ...
# 118686  2021-01-31      0.3550      0.8000     0.3509       0.7064
# 118687  2020-12-31      0.4294      0.4483     0.3100       0.3548
# 118688  2020-11-30      0.3214      0.5285     0.3057       0.4292
# 118689  2020-10-31      0.4098      0.4349     0.3150       0.3219
# 118690  2020-09-30      0.6121      0.6322     0.3357       0.4091
#
#         open (USD).1  high (USD).1  low (USD).1  close (USD).1        volume  \
# 0            68.7000       69.2000      68.2000        69.0000  2.171491e+03
# 1            69.7000       70.2000      68.2000        68.7000  2.555457e+04
# 2            73.4000       74.1000      68.5000        69.8000  6.431654e+04
# 3            70.8000       74.3000      70.0000        73.5000  5.979686e+04
# 4            71.8000       72.1000      70.2000        70.8000  2.978446e+04
# ...              ...           ...          ...            ...           ...
# 118686        0.3550        0.8000       0.3509         0.7064  7.008664e+08
# 118687        0.4294        0.4483       0.3100         0.3548  1.941776e+08
# 118688        0.3214        0.5285       0.3057         0.4292  2.325502e+08
# 118689        0.4098        0.4349       0.3150         0.3219  1.249353e+08
# 118690        0.6121        0.6322       0.3357         0.4091  2.062734e+08
#
#         market cap (USD) time_frame symbol   {}
# 0           2.171491e+03      daily   AAVE  NaN
# 1           2.555457e+04      daily   AAVE  NaN
# 2           6.431654e+04      daily   AAVE  NaN
# 3           5.979686e+04      daily   AAVE  NaN
# 4           2.978446e+04      daily   AAVE  NaN
# ...                  ...        ...    ...  ...
# 118686      7.008664e+08    monthly    ZRX  NaN
# 118687      1.941776e+08    monthly    ZRX  NaN
# 118688      2.325502e+08    monthly    ZRX  NaN
# 118689      1.249353e+08    monthly    ZRX  NaN
# 118690      2.062734e+08    monthly    ZRX  NaN
#
# [118691 rows x 14 columns]

# %%
allData = pd.read_csv('./data/all_data.csv')
allData.drop(columns = ['Unnamed: 0', 'open (USD).1', 'high (USD).1', 'low (USD).1', 'close (USD).1', '{}'], inplace = True)
allData.columns = ['timestamp', 'open', 'high', 'low', 'close', 'volume', 'marketcap', 'timeframe', 'symbol']
allData = allData[['timeframe', 'symbol', 'timestamp', 'open', 'high', 'low', 'close', 'volume', 'marketcap']]
allData
# Out:
#        timeframe symbol   timestamp     open     high      low    close  \
# 0          daily   AAVE  2023-05-08  68.7000  69.2000  68.2000  69.0000
# 1          daily   AAVE  2023-05-07  69.7000  70.2000  68.2000  68.7000
# 2          daily   AAVE  2023-05-06  73.4000  74.1000  68.5000  69.8000
# 3          daily   AAVE  2023-05-05  70.8000  74.3000  70.0000  73.5000
# 4          daily   AAVE  2023-05-04  71.8000  72.1000  70.2000  70.8000
# ...          ...    ...         ...      ...      ...      ...      ...
# 118686   monthly    ZRX  2021-01-31   0.3550   0.8000   0.3509   0.7064
# 118687   monthly    ZRX  2020-12-31   0.4294   0.4483   0.3100   0.3548
# 118688   monthly    ZRX  2020-11-30   0.3214   0.5285   0.3057   0.4292
# 118689   monthly    ZRX  2020-10-31   0.4098   0.4349   0.3150   0.3219
# 118690   monthly    ZRX  2020-09-30   0.6121   0.6322   0.3357   0.4091
#
#               volume     marketcap
# 0       2.171491e+03  2.171491e+03
# 1       2.555457e+04  2.555457e+04
# 2       6.431654e+04  6.431654e+04
# 3       5.979686e+04  5.979686e+04
# 4       2.978446e+04  2.978446e+04
# ...              ...           ...
# 118686  7.008664e+08  7.008664e+08
# 118687  1.941776e+08  1.941776e+08
# 118688  2.325502e+08  2.325502e+08
# 118689  1.249353e+08  1.249353e+08
# 118690  2.062734e+08  2.062734e+08
#
# [118691 rows x 9 columns]

# %%
allData['symbol'].unique()
# Out:
# array(['AAVE', 'ADA', 'ADX', 'AION', 'ALGO', 'AMP', 'ANC', 'ANT', 'ARDR',
#        'ATM', 'ATOM', 'AVAX', 'BAND', 'BAT', 'BCC', 'BCH', 'BLZ', 'BNB',
#        'BNT', 'BTC', 'BTG', 'BTS', 'BTT', 'BUSD', 'CAKE', 'COMP', 'CTXC',
#        'CVC', 'DAI', 'DAR', 'DASH', 'DATA', 'DCR', 'DENT', 'DGB', 'DNT',
#        'DOGE', 'DOT', 'EGLD', 'ELF', 'ENJ', 'EOS', 'ETC', 'ETH', 'FIL',
#        'FTT', 'FUN', 'GAS', 'GNO', 'GRT', 'GTC', 'GTO', 'GXS', 'ICX',
#        'IOST', 'IOTA', 'IOTX', 'KMD', 'KNC', 'KSM', 'LEND', 'LINK',
#        'LOOM', 'LRC', 'LSK', 'LTC', 'LUNA', 'MANA', 'MATIC', 'MCO',
#        'MITH', 'MKR', 'MLN', 'NANO', 'NBT', 'NEBL', 'NEO', 'NMR', 'NPXS',
#        'NULS', 'OAX', 'OMG', 'ONT', 'ORN', 'POLY', 'POWR', 'QTUM',
#        'QUICK', 'REP', 'REQ', 'RLC', 'RUNE', 'SC', 'SHIB', 'SOL', 'SNX',
#        'STEEM', 'STORJ', 'STORM', 'STRAT', 'STX', 'SYS', 'THETA', 'TRIBE',
#        'TRX', 'TUSD', 'UNI', 'UST', 'UTK', 'VEN', 'VIB', 'WAN', 'WAVES',
#        'WBTC', 'XEM', 'XLM', 'XRP', 'XTZ', 'XVG', 'XZC', 'ZEC', 'ZEN',
#        'ZIL', 'ZRX'], dtype=object)
