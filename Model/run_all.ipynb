# %%
# https://www.relataly.com/crypto-market-cluster-analysis-using-affinity-propagation-python/8114/

# %%
# reload modules
# %load_ext autoreload
# %autoreload 2

# %%
import data_load
import clustering_model

# %% [markdown]
# # Data Load

# %%
basic_data = data_load.load_basic_data()
print(basic_data.shape)
basic_data.head()
# Out:
# (320, 18)
#      id      name symbol      slug  \
# 0     1   Bitcoin    BTC   bitcoin
# 1  1027  Ethereum    ETH  ethereum
# 2  1839       BNB    BNB       bnb
# 3    52       XRP    XRP       xrp
# 4  2010   Cardano    ADA   cardano
#
#                                                 tags  cmcRank  \
# 0  ['mineable', 'pow', 'sha-256', 'store-of-value...        1
# 1  ['pos', 'smart-contracts', 'ethereum-ecosystem...        2
# 2  ['marketplace', 'centralized-exchange', 'payme...        4
# 3  ['medium-of-exchange', 'enterprise-solutions',...        6
# 4  ['dpos', 'pos', 'platform', 'research', 'smart...        7
#
#    marketPairCount  circulatingSupply  selfReportedCirculatingSupply  \
# 0            10278       1.942026e+07                            0.0
# 1             7068       1.202176e+08                            0.0
# 2             1475       1.558506e+08                            0.0
# 3              972       5.225429e+10                            0.0
# 4              850       3.495589e+10                            0.0
#
#     totalSupply     maxSupply  isActive               lastUpdated  \
# 0  1.942026e+07  2.100000e+07         1  2023-07-05T05:01:00.000Z
# 1  1.202176e+08           NaN         1  2023-07-05T05:01:00.000Z
# 2  1.558506e+08           NaN         1  2023-07-05T05:01:00.000Z
# 3  9.998866e+10  1.000000e+11         1  2023-07-05T05:01:00.000Z
# 4  3.595238e+10  4.500000e+10         1  2023-07-05T05:01:00.000Z
#
#                   dateAdded  \
# 0  2010-07-13T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2013-08-04T00:00:00.000Z
# 4  2017-10-01T00:00:00.000Z
#
#                                               quotes  isAudited  \
# 0  [{'name': 'USD', 'price': 30837.28822501044, '...      False
# 1  [{'name': 'USD', 'price': 1937.196498176435, '...      False
# 2  [{'name': 'USD', 'price': 243.528037849361, 'v...       True
# 3  [{'name': 'USD', 'price': 0.49092645510058036,...       True
# 4  [{'name': 'USD', 'price': 0.29356399231299274,...      False
#
#                                        auditInfoList platform
# 0                                                NaN      NaN
# 1                                                 []      NaN
# 2  [{'coinId': '1839', 'auditor': 'CertiK', 'audi...      NaN
# 3  [{'coinId': '52', 'auditor': 'CertiK', 'auditS...      NaN
# 4                                                NaN      NaN

# %%
historical_data = data_load.load_historical_data(basic_data)
print(historical_data.shape)
historical_data.head()
# Out:
# (499123, 10)
#   symbol        date          open          high           low         close  \
# 0    BTC  2023-07-04  31156.864922  31325.198166  30659.355893  30777.581511
# 1    BTC  2023-07-03  30624.516311  31375.613252  30586.513433  31156.439492
# 2    BTC  2023-07-02  30587.269956  30766.139747  30264.018714  30620.770263
# 3    BTC  2023-07-01  30471.847563  30641.289323  30328.864749  30590.079072
# 4    BTC  2023-06-30  30441.353759  31256.862700  29600.275939  30477.251282
#
#             avg    return        volume     marketcap
# 0  30967.223216 -0.012173  1.281083e+10  5.977022e+11
# 1  30890.477901  0.017369  1.527188e+10  6.050312e+11
# 2  30604.020110  0.001095  1.053342e+10  5.946020e+11
# 3  30530.963317  0.003880  9.086607e+09  5.939744e+11
# 4  30459.302521  0.001179  2.638731e+10  5.917583e+11

# %% [markdown]
# # Clustering Model

# %%
return_data = clustering_model.load_return_data(historical_data)
print(return_data.shape)
return_data.head()
# Out:
# (730, 305)
#       1INCH      AAVE      ABBC       ACH       ADA       ADS     AERGO  \
# 0 -0.018895  0.110853 -0.035474  0.008349 -0.038545  0.033898 -0.001828
# 1  0.139607  0.028900 -0.027834  0.052004  0.009497  0.068308  0.028235
# 2 -0.027239 -0.007797 -0.033193  0.000846 -0.009204  0.015144 -0.021960
# 3 -0.090956 -0.072816 -0.043090 -0.137035 -0.053252 -0.013459 -0.087418
# 4  0.027571  0.043622  0.060045  0.021621  0.016731  0.086890  0.024770
#
#        AGIX       AKT      ALGO  ...       XVS       XYO       YFI      YFII  \
# 0  0.046165  0.053214 -0.006942  ... -0.014598 -0.039070 -0.027204  0.032655
# 1  0.060823 -0.076748  0.045610  ...  0.056719  0.031629  0.108903  0.013975
# 2  0.035163 -0.018598 -0.008445  ... -0.027023  0.005628 -0.016337 -0.045094
# 3 -0.081541 -0.096779 -0.041261  ... -0.098932 -0.065893 -0.065557 -0.026339
# 4  0.159592  0.032592  0.044245  ...  0.023543  0.013857  0.013423  0.029807
#
#         ZEC       ZEN       ZIL       ZRX   ankrETH     stETH
# 0 -0.073451 -0.061713 -0.038892 -0.040905 -0.046202 -0.050650
# 1  0.055164  0.071251  0.011328  0.026541  0.051585  0.057460
# 2  0.004969 -0.050212  0.004417  0.104815 -0.001737 -0.007142
# 3 -0.076633 -0.070618 -0.078269  0.044194 -0.090706 -0.079457
# 4  0.016537  0.017902  0.001747  0.006463  0.016393  0.010827
#
# [5 rows x 305 columns]

# %%
clusters_data = clustering_model.load_clusters_data(return_data)
print(clusters_data['cluster'].unique().shape)
clusters_data.head()
# Out:
# (95,)
#   symbol  cluster
# 0   ABBC        0
# 1    ACH        1
# 2   AMPL        2
# 3    AOG        3
# 4    BFC        3

# %% [markdown]
# # Regression Model

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import r2_score

# %%
days = 30  #TODO: add to config

# %%
clusters_data['cluster'] = clusters_data['cluster'].map('{:02}'.format)
clusters_data
# Out:
#     symbol cluster
# 0     ABBC      00
# 1      ACH      01
# 2     AMPL      02
# 3      AOG      03
# 4      BFC      03
# ..     ...     ...
# 300   XAUT      91
# 301    XDC      92
# 302    FUN      93
# 303    XVG      93
# 304    XYO      94
#
# [305 rows x 2 columns]

# %%
regression_data = historical_data.merge(
    clusters_data,
    on='symbol',
    how='inner'
)

regression_data
# Out:
#        symbol        date          open          high           low  \
# 0         BTC  2023-07-04  31156.864922  31325.198166  30659.355893
# 1         BTC  2023-07-03  30624.516311  31375.613252  30586.513433
# 2         BTC  2023-07-02  30587.269956  30766.139747  30264.018714
# 3         BTC  2023-07-01  30471.847563  30641.289323  30328.864749
# 4         BTC  2023-06-30  30441.353759  31256.862700  29600.275939
# ...       ...         ...           ...           ...           ...
# 489804    SRM  2020-08-15      1.858135      1.893875      1.653225
# 489805    SRM  2020-08-14      2.029597      2.164305      1.821478
# 489806    SRM  2020-08-13      1.682308      2.221409      1.639467
# 489807    SRM  2020-08-12      1.555740      1.982487      1.555740
# 489808    SRM  2020-08-11      0.110091      1.607618      0.110006
#
#                close           avg     return        volume     marketcap  \
# 0       30777.581511  30967.223216  -0.012173  1.281083e+10  5.977022e+11
# 1       31156.439492  30890.477901   0.017369  1.527188e+10  6.050312e+11
# 2       30620.770263  30604.020110   0.001095  1.053342e+10  5.946020e+11
# 3       30590.079072  30530.963317   0.003880  9.086607e+09  5.939744e+11
# 4       30477.251282  30459.302521   0.001179  2.638731e+10  5.917583e+11
# ...              ...           ...        ...           ...           ...
# 489804      1.664159      1.761147  -0.104393  4.380330e+07  8.320793e+07
# 489805      1.861319      1.945458  -0.082912  6.367864e+07  9.306594e+07
# 489806      2.029851      1.856079   0.206587  1.492122e+08  0.000000e+00
# 489807      1.690087      1.622914   0.086356  2.625532e+08  0.000000e+00
# 489808      1.570353      0.840222  13.264118  2.112328e+08  0.000000e+00
#
#        cluster
# 0           89
# 1           89
# 2           89
# 3           89
# 4           89
# ...        ...
# 489804      29
# 489805      29
# 489806      29
# 489807      29
# 489808      29
#
# [489809 rows x 11 columns]

# %%
regression_data['future_return'] = ((1 + regression_data['return']).rolling(window=days).apply(np.prod, raw=True) - 1).shift(1)
regression_data['future_risk'] = regression_data['return'].rolling(window=days).agg(np.var)
regression_data.loc[regression_data.groupby('symbol').cumcount() < days, ['future_return', 'future_risk']] = np.nan
regression_data.dropna(inplace=True)  # subset='future_return'
regression_data.reset_index(drop=True, inplace=True)
regression_data
# Out:
#        symbol        date          open          high           low  \
# 0         BTC  2023-06-04  27075.122073  27407.018570  26968.224141
# 1         BTC  2023-06-03  27252.323333  27317.051854  26958.003740
# 2         BTC  2023-06-02  26824.556981  27303.861687  26574.644421
# 3         BTC  2023-06-01  27218.412376  27346.105483  26671.721156
# 4         BTC  2023-05-31  27700.530089  27831.677804  26866.453944
# ...       ...         ...           ...           ...           ...
# 480633    SRM  2020-08-15      1.858135      1.893875      1.653225
# 480634    SRM  2020-08-14      2.029597      2.164305      1.821478
# 480635    SRM  2020-08-13      1.682308      2.221409      1.639467
# 480636    SRM  2020-08-12      1.555740      1.982487      1.555740
# 480637    SRM  2020-08-11      0.110091      1.607618      0.110006
#
#                close           avg     return        volume     marketcap  \
# 0       27119.067193  27097.094633   0.001623  9.360912e+09  5.259202e+11
# 1       27075.129398  27163.726366  -0.006502  8.385597e+09  5.250436e+11
# 2       27249.588949  27037.072965   0.015845  1.483741e+10  5.284044e+11
# 3       26819.973220  27019.192798  -0.014639  1.467897e+10  5.200450e+11
# 4       27219.658608  27460.094348  -0.017360  1.565637e+10  5.277732e+11
# ...              ...           ...        ...           ...           ...
# 480633      1.664159      1.761147  -0.104393  4.380330e+07  8.320793e+07
# 480634      1.861319      1.945458  -0.082912  6.367864e+07  9.306594e+07
# 480635      2.029851      1.856079   0.206587  1.492122e+08  0.000000e+00
# 480636      1.690087      1.622914   0.086356  2.625532e+08  0.000000e+00
# 480637      1.570353      0.840222  13.264118  2.112328e+08  0.000000e+00
#
#        cluster  future_return  future_risk
# 0           89       0.138635     0.000623
# 1           89       0.154538     0.000621
# 2           89       0.127448     0.000625
# 3           89       0.144059     0.000638
# 4           89       0.122955     0.000653
# ...        ...            ...          ...
# 480633      29       0.468858     0.015578
# 480634      29       0.293591     0.015881
# 480635      29       0.201487     0.017118
# 480636      29       0.438105     0.017256
# 480637      29       0.507497     5.859428
#
# [480638 rows x 13 columns]

# %%
regression_max_data = regression_data[['symbol', 'open', 'high', 'low', 'close', 'avg', 'return', 'volume', 'marketcap', 'future_return', 'future_risk']].groupby('symbol').max()
regression_max_data = regression_data[['symbol']].merge(
    regression_max_data,
    on='symbol',
    how='left'
)
regression_max_data
# Out:
#        symbol          open          high           low         close  \
# 0         BTC  67549.735581  68789.625939  66382.061008  67566.830088
# 1         BTC  67549.735581  68789.625939  66382.061008  67566.830088
# 2         BTC  67549.735581  68789.625939  66382.061008  67566.830088
# 3         BTC  67549.735581  68789.625939  66382.061008  67566.830088
# 4         BTC  67549.735581  68789.625939  66382.061008  67566.830088
# ...       ...           ...           ...           ...           ...
# 480633    SRM     12.504232     13.720617     11.629815     12.482537
# 480634    SRM     12.504232     13.720617     11.629815     12.482537
# 480635    SRM     12.504232     13.720617     11.629815     12.482537
# 480636    SRM     12.504232     13.720617     11.629815     12.482537
# 480637    SRM     12.504232     13.720617     11.629815     12.482537
#
#                  avg     return        volume     marketcap  future_return  \
# 0       67260.781839   0.416811  3.509679e+11  1.274831e+12       4.388445
# 1       67260.781839   0.416811  3.509679e+11  1.274831e+12       4.388445
# 2       67260.781839   0.416811  3.509679e+11  1.274831e+12       4.388445
# 3       67260.781839   0.416811  3.509679e+11  1.274831e+12       4.388445
# 4       67260.781839   0.416811  3.509679e+11  1.274831e+12       4.388445
# ...              ...        ...           ...           ...            ...
# 480633     12.179657  13.264118  2.871741e+09  1.196232e+09       2.756203
# 480634     12.179657  13.264118  2.871741e+09  1.196232e+09       2.756203
# 480635     12.179657  13.264118  2.871741e+09  1.196232e+09       2.756203
# 480636     12.179657  13.264118  2.871741e+09  1.196232e+09       2.756203
# 480637     12.179657  13.264118  2.871741e+09  1.196232e+09       2.756203
#
#         future_risk
# 0          0.017703
# 1          0.017703
# 2          0.017703
# 3          0.017703
# 4          0.017703
# ...             ...
# 480633     5.859428
# 480634     5.859428
# 480635     5.859428
# 480636     5.859428
# 480637     5.859428
#
# [480638 rows x 11 columns]

# %%
regression_normalized_data = regression_data[['future_return', 'future_risk', 'open', 'high', 'low', 'close', 'avg', 'return', 'volume', 'marketcap']] / regression_max_data[['future_return', 'future_risk', 'open', 'high', 'low', 'close', 'avg', 'return', 'volume', 'marketcap']]
regression_normalized_data = regression_data[['symbol', 'cluster']].join(
    regression_normalized_data
)
regression_normalized_data
# Out:
#   Cell In[18], line 1
#     regression_normalized_data = regression_data.loc[:,'open':'marketcap'] / regression_max_data[:,['future_return', 'future_risk', 'open':'marketcap']]
#                                                                                                                                           ^
# SyntaxError: invalid syntax

# %%
regression_normalized_data = pd.get_dummies(regression_normalized_data)
regression_normalized_data
# Out:
#         future_return  future_risk      open      high       low     close  \
# 0            0.031591     0.035165  0.400818  0.398418  0.406258  0.401367
# 1            0.035215     0.035097  0.403441  0.397110  0.406104  0.400716
# 2            0.029042     0.035322  0.397108  0.396918  0.400329  0.403298
# 3            0.032827     0.036034  0.402939  0.397532  0.401791  0.396940
# 4            0.028018     0.036897  0.410076  0.404591  0.404725  0.402855
# ...               ...          ...       ...       ...       ...       ...
# 480633       0.170110     0.002659  0.148601  0.138031  0.142154  0.133319
# 480634       0.106520     0.002710  0.162313  0.157741  0.156621  0.149114
# 480635       0.073103     0.002921  0.134539  0.161903  0.140971  0.162615
# 480636       0.158952     0.002945  0.124417  0.144490  0.133772  0.135396
# 480637       0.184129     1.000000  0.008804  0.117168  0.009459  0.125804
#
#              avg    return    volume  marketcap  ...  cluster_85  cluster_86  \
# 0       0.402866  0.003894  0.026672   0.412541  ...       False       False
# 1       0.403857 -0.015599  0.023893   0.411853  ...       False       False
# 2       0.401974  0.038015  0.042276   0.414490  ...       False       False
# 3       0.401708 -0.035120  0.041824   0.407932  ...       False       False
# 4       0.408263 -0.041649  0.044609   0.413994  ...       False       False
# ...          ...       ...       ...        ...  ...         ...         ...
# 480633  0.144597 -0.007870  0.015253   0.069558  ...       False       False
# 480634  0.159730 -0.006251  0.022174   0.077799  ...       False       False
# 480635  0.152392  0.015575  0.051959   0.000000  ...       False       False
# 480636  0.133248  0.006510  0.091427   0.000000  ...       False       False
# 480637  0.068986  1.000000  0.073556   0.000000  ...       False       False
#
#         cluster_87  cluster_88  cluster_89  cluster_90  cluster_91  \
# 0            False       False        True       False       False
# 1            False       False        True       False       False
# 2            False       False        True       False       False
# 3            False       False        True       False       False
# 4            False       False        True       False       False
# ...            ...         ...         ...         ...         ...
# 480633       False       False       False       False       False
# 480634       False       False       False       False       False
# 480635       False       False       False       False       False
# 480636       False       False       False       False       False
# 480637       False       False       False       False       False
#
#         cluster_92  cluster_93  cluster_94
# 0            False       False       False
# 1            False       False       False
# 2            False       False       False
# 3            False       False       False
# 4            False       False       False
# ...            ...         ...         ...
# 480633       False       False       False
# 480634       False       False       False
# 480635       False       False       False
# 480636       False       False       False
# 480637       False       False       False
#
# [480638 rows x 410 columns]

# %%
regr = linear_model.LinearRegression()
x = regression_normalized_data.loc[:, 'open':]
y = regression_normalized_data[['future_return', 'future_risk']]

regr.fit(x, y)
y_ = regr.predict(x)

print(f'RSQ: {(100 * r2_score(y, y_)):.2f}%')
# Out:
# RSQ: 14.01%
