# %% [markdown]
# # Import Modules and Config

# %%
import data_load
import clustering_model
import regression_model
# %load_ext autoreload
# %autoreload 2

# %%
UPDATE_DATA_LOAD = False
UPDATE_CLUSTERING_MODEL = True
UPDATE_REGRESSION_MODEL = True

# %% [markdown]
# # Data Load

# %%
basic_df = data_load.load_basic_data(
    selected_symbols=20, 
    max_date_added_year=2020, 
    min_last_update_year=2023, 
    min_market_pairs=6, 
    update=UPDATE_DATA_LOAD
)
print(basic_df.shape)
basic_df.head()
# Out:
# (19, 19)
#      id         name symbol      slug
# 0     1      Bitcoin    BTC   bitcoin  \
# 1  1027     Ethereum    ETH  ethereum
# 2   825  Tether USDt   USDT    tether
# 3  1839          BNB    BNB       bnb
# 4    52          XRP    XRP       xrp
#
#                                                 tags  cmcRank
# 0  ['mineable', 'pow', 'sha-256', 'store-of-value...        1  \
# 1  ['pos', 'smart-contracts', 'ethereum-ecosystem...        2
# 2  ['payments', 'stablecoin', 'asset-backed-stabl...        3
# 3  ['marketplace', 'centralized-exchange', 'payme...        4
# 4  ['medium-of-exchange', 'enterprise-solutions',...        5
#
#    marketPairCount  circulatingSupply  selfReportedCirculatingSupply
# 0            10543       1.953815e+07                              0  \
# 1             7745       1.202636e+08                              0
# 2            65388       8.651725e+10                              0
# 3             1752       1.517021e+08                              0
# 4             1136       5.365277e+10                              0
#
#     totalSupply     maxSupply  isActive               lastUpdated
# 0  1.953815e+07  2.100000e+07         1  2023-11-10T06:34:00.000Z  \
# 1  1.202636e+08           NaN         1  2023-11-10T06:34:00.000Z
# 2  8.962366e+10           NaN         1  2023-11-10T06:33:00.000Z
# 3  1.517021e+08           NaN         1  2023-11-10T06:33:00.000Z
# 4  9.998824e+10  1.000000e+11         1  2023-11-10T06:34:00.000Z
#
#                   dateAdded
# 0  2010-07-13T00:00:00.000Z  \
# 1  2015-08-07T00:00:00.000Z
# 2  2015-02-25T00:00:00.000Z
# 3  2017-07-25T00:00:00.000Z
# 4  2013-08-04T00:00:00.000Z
#
#                                               quotes  isAudited     badges
# 0  [{'name': 'USD', 'price': 36621.182092247414, ...      False     [1, 5]  \
# 1  [{'name': 'USD', 'price': 2110.4244127662914, ...      False  [1, 3, 5]
# 2  [{'name': 'USD', 'price': 1.0000804496610904, ...       True         []
# 3  [{'name': 'USD', 'price': 254.62419901858183, ...       True        [3]
# 4  [{'name': 'USD', 'price': 0.6621545512486472, ...       True         []
#
#                                        auditInfoList
# 0                                                NaN  \
# 1                                                 []
# 2  [{'coinId': '825', 'auditor': 'CertiK', 'audit...
# 3  [{'coinId': '1839', 'auditor': 'CertiK', 'audi...
# 4  [{'coinId': '52', 'auditor': 'CertiK', 'auditS...
#
#                                             platform
# 0                                                NaN
# 1                                                NaN
# 2  {'id': 1, 'name': 'Ethereum', 'symbol': 'ETH',...
# 3                                                NaN
# 4                                                NaN

# %%
symbols_list = basic_df["symbol"].to_list()
historical_df = data_load.load_historical_data(
    symbols_list,
    update=UPDATE_DATA_LOAD
)
print(historical_df.shape)
historical_df.head()
# Out:
# (42819, 10)
#   symbol        date          open          high           low         close
# 0    BTC  2023-11-09  35633.634394  37926.256797  35592.103252  36693.123634  \
# 1    BTC  2023-11-08  35419.476717  35994.416531  35147.800805  35655.276081
# 2    BTC  2023-11-07  35047.793633  35892.416370  34545.815095  35443.561361
# 3    BTC  2023-11-06  35044.789919  35286.026827  34765.364847  35037.369441
# 4    BTC  2023-11-05  35090.013021  35340.339719  34594.242577  35049.355924
#
#             avg    return        volume     marketcap
# 0  36163.379014  0.029733  3.776267e+10  7.169024e+11
# 1  35537.376399  0.006657  1.729539e+10  6.965953e+11
# 2  35245.677497  0.011292  1.883474e+10  6.924256e+11
# 3  35041.079680 -0.000212  1.269344e+10  6.844605e+11
# 4  35069.684473 -0.001159  1.241274e+10  6.846677e+11

# %%
selected_df = data_load.load_selected_data(
    historical_df, 
    selected_days=1460, 
    end_date="2023-10-10", 
    update=UPDATE_DATA_LOAD
)
print(selected_df.shape)
selected_df.head()
# Out:
# (17520, 10)
#   symbol        date          open          high           low         close
# 0    BTC  2023-10-10  27589.201102  27715.848347  27301.655078  27391.019517  \
# 1    BTC  2023-10-09  27934.472162  27989.470902  27302.561919  27583.678595
# 2    BTC  2023-10-08  27971.678107  28102.170391  27740.663024  27935.089581
# 3    BTC  2023-10-07  27946.781633  28028.092087  27870.423458  27968.838871
# 4    BTC  2023-10-06  27412.122424  28252.537570  27215.552446  27946.596780
#
#             avg    return        volume     marketcap
# 0  27490.110310 -0.007183  9.973351e+09  5.343984e+11
# 1  27759.075379 -0.012558  1.200767e+10  5.381279e+11
# 2  27953.383844 -0.001308  7.916875e+09  5.449575e+11
# 3  27957.810252  0.000789  6.553044e+09  5.455899e+11
# 4  27679.359602  0.019498  1.349239e+10  5.451267e+11

# %% [markdown]
# # Clustering Model

# %%
# TODO: Add a KPI to measure how much the model worked

# %%
return_df = clustering_model.load_return_data(
    selected_df, 
    update=UPDATE_CLUSTERING_MODEL
)
print(return_df.shape)
return_df.head()
# Out:
# return data file saved.
# (1460, 12)
#                  ADA       BCH       BNB       BTC      DOGE       ETH
# 2019-10-12  0.000053  0.010657  0.033728  0.002512  0.005015 -0.009354  \
# 2019-10-13  0.019357 -0.004072  0.060925 -0.001907  0.046538  0.006711
# 2019-10-14  0.011243  0.020693  0.008273  0.006472  0.039529  0.027097
# 2019-10-15 -0.048566 -0.024983  0.006446 -0.020074 -0.014151 -0.029795
# 2019-10-16 -0.025635 -0.020902 -0.036556 -0.019153  0.039411 -0.029393
#
#                  LTC     MATIC       TRX      USDC      USDT       XRP
# 2019-10-12 -0.007473 -0.020521 -0.016072 -0.004148 -0.007881  0.007657
# 2019-10-13  0.013802 -0.036510  0.025739  0.000226  0.000532  0.016974
# 2019-10-14  0.004535  0.015636  0.036808 -0.000418 -0.000642  0.068065
# 2019-10-15 -0.036190 -0.058215 -0.058775  0.001337 -0.000194 -0.026097
# 2019-10-16 -0.037528 -0.032846 -0.028902  0.000364  0.002089 -0.014730

# %%
clusters_df = clustering_model.load_clusters_data(
    return_df, 
    UPDATE_CLUSTERING_MODEL
)
clusters_number = clusters_df['cluster'].unique().shape[0]
print(clusters_number, 'clusters')
clusters_df.head()
# Out:
# Clusters data file saved.
# 3 clusters
#   symbol cluster
# 0   DOGE       0
# 1    ADA       1
# 2    BCH       1
# 3    BNB       1
# 4    BTC       1

# %% [markdown]
# # Regression Model

# %%
# TODO: Use ANN models
# TODO: Add financial indexes to regression model
# TODO: Add more regression models (LogisticRegression(), SVC(kernel='poly', probability=True), XGBClassifier(), etc)
# TODO: Grid search over parameters

# %%
regression_df = regression_model.load_regression_data(
    selected_df, 
    clusters_df, 
    future_days=30, 
    update=UPDATE_REGRESSION_MODEL
)
print(regression_df.shape)
regression_df.head()
# Out:
# (17520, 45)
#   symbol       date          open          high           low         close
# 0    BTC 2023-10-10  27589.201102  27715.848347  27301.655078  27391.019517  \
# 1    BTC 2023-10-09  27934.472162  27989.470902  27302.561919  27583.678595
# 2    BTC 2023-10-08  27971.678107  28102.170391  27740.663024  27935.089581
# 3    BTC 2023-10-07  27946.781633  28028.092087  27870.423458  27968.838871
# 4    BTC 2023-10-06  27412.122424  28252.537570  27215.552446  27946.596780
#
#             avg    return        volume     marketcap  ...  symbol_MATIC
# 0  27490.110310 -0.007183  9.973351e+09  5.343984e+11  ...         False  \
# 1  27759.075379 -0.012558  1.200767e+10  5.381279e+11  ...         False
# 2  27953.383844 -0.001308  7.916875e+09  5.449575e+11  ...         False
# 3  27957.810252  0.000789  6.553044e+09  5.455899e+11  ...         False
# 4  27679.359602  0.019498  1.349239e+10  5.451267e+11  ...         False
#
#    symbol_TRX  symbol_USDC  symbol_USDT  symbol_XRP  cluster_0  cluster_1
# 0       False        False        False       False      False       True  \
# 1       False        False        False       False      False       True
# 2       False        False        False       False      False       True
# 3       False        False        False       False      False       True
# 4       False        False        False       False      False       True
#
#    cluster_2  future_return  future_risk
# 0      False            NaN          NaN
# 1      False            NaN          NaN
# 2      False            NaN          NaN
# 3      False            NaN          NaN
# 4      False            NaN          NaN
#
# [5 rows x 45 columns]

# %%
# regression_df.plot.scatter(x='close', y='future_return')

# %%
prediction_df = regression_model.load_prediction_data(
    regression_df, 
    model='random_forest_regressor', 
    update=UPDATE_REGRESSION_MODEL
)
print(prediction_df.shape)
prediction_df.head()
# Out:
# Train R2: 97.06%
# Test R2: 82.50%
# (12, 45)
#   symbol       date          open          high           low         close
# 0    ADA 2023-10-10      0.251631      0.253101      0.247501      0.249141  \
# 1    BCH 2023-10-10    218.438845    219.819033    210.992026    212.499744
# 2    BNB 2023-10-10    205.750092    210.454291    205.750092    208.576880
# 3    BTC 2023-10-10  27589.201102  27715.848347  27301.655078  27391.019517
# 4   DOGE 2023-10-10      0.058779      0.059204      0.058608      0.059025
#
#             avg    return        volume     marketcap  ...  symbol_MATIC
# 0      0.250386 -0.009894  1.101835e+08  8.757862e+09  ...         False  \
# 1    215.469294 -0.027189  1.489568e+08  4.149692e+09  ...         False
# 2    207.163486  0.013739  4.419594e+08  3.208859e+10  ...         False
# 3  27490.110310 -0.007183  9.973351e+09  5.343984e+11  ...         False
# 4      0.058902  0.004183  1.233113e+08  8.343727e+09  ...         False
#
#    symbol_TRX  symbol_USDC  symbol_USDT  symbol_XRP  cluster_0  cluster_1
# 0       False        False        False       False      False       True  \
# 1       False        False        False       False      False       True
# 2       False        False        False       False      False       True
# 3       False        False        False       False      False       True
# 4       False        False        False       False       True      False
#
#    cluster_2  future_return  future_risk
# 0      False      -0.056791     0.006572
# 1      False       0.433816     0.016205
# 2      False      -0.109583     0.010016
# 3      False       0.050858     0.008438
# 4      False       0.147145     0.000919
#
# [5 rows x 45 columns]

# %% [markdown]
# # Portfolio Selection

# %%
# TODO: Use clustering models
# TODO: Add CAPM Model
# TODO: Add Black-Litterman allocation?
# TODO: long and short? weight_bounds=(-1, 1)
# TODO: non-covariance models: sparse portfolio, minimum variance portfolio, etc

# %%
close_df = selected_df[["date", "symbol", "close"]].copy()
close_df = close_df.pivot(index="date", columns="symbol")
close_df = close_df["close"]
close_df.columns.name = None
close_df
# Out:
#                  ADA         BCH         BNB           BTC      DOGE
# date
# 2019-10-12  0.040542  225.101983   17.277907   8336.555274  0.002340  \
# 2019-10-13  0.041325  224.123238   18.308025   8321.005747  0.002447
# 2019-10-14  0.041789  228.589232   18.459479   8374.686447  0.002545
# 2019-10-15  0.039766  222.827785   18.544652   8205.369316  0.002510
# 2019-10-16  0.038741  218.203116   17.840050   8047.526863  0.002607
# ...              ...         ...         ...           ...       ...
# 2023-10-06  0.264872  230.995594  213.555532  27946.596780  0.061426
# 2023-10-07  0.258735  230.317247  212.364475  27968.838871  0.061455
# 2023-10-08  0.256629  228.085600  211.519983  27935.089581  0.061008
# 2023-10-09  0.251642  218.439720  205.750960  27583.678595  0.058779
# 2023-10-10  0.249141  212.499744  208.576880  27391.019517  0.059025
#
#                     ETH        LTC     MATIC       TRX      USDC      USDT
# date
# 2019-10-12   180.826640  55.982870  0.015631  0.015741  1.002841  1.004475  \
# 2019-10-13   182.075153  56.713995  0.015021  0.016137  1.003169  1.004942
# 2019-10-14   186.960906  56.975401  0.015256  0.016732  1.002749  1.004195
# 2019-10-15   181.406060  54.944208  0.014415  0.015744  1.004290  1.004050
# 2019-10-16   176.013511  52.923107  0.013942  0.015287  1.004679  1.006127
# ...                 ...        ...       ...       ...       ...       ...
# 2023-10-06  1645.831487  65.533186  0.564189  0.087266  0.999991  1.000436
# 2023-10-07  1634.511273  65.485643  0.563805  0.088129  0.999960  1.000550
# 2023-10-08  1633.548572  65.364546  0.561185  0.088024  0.999969  1.000460
# 2023-10-09  1579.806608  63.111057  0.529774  0.086199  0.999902  1.000081
# 2023-10-10  1567.712967  63.621071  0.517559  0.086275  0.999976  1.000088
#
#                  XRP
# date
# 2019-10-12  0.273191
# 2019-10-13  0.277765
# 2019-10-14  0.296523
# 2019-10-15  0.288702
# 2019-10-16  0.284640
# ...              ...
# 2023-10-06  0.526193
# 2023-10-07  0.521906
# 2023-10-08  0.517961
# 2023-10-09  0.503227
# 2023-10-10  0.497436
#
# [1460 rows x 12 columns]

# %%
# Mean Variance

from pypfopt.expected_returns import mean_historical_return
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.efficient_frontier import EfficientFrontier

m = mean_historical_return(close_df)  # mu = expected_returns.mean_historical_return(df)
s = CovarianceShrinkage(close_df).ledoit_wolf()  # S = risk_models.sample_cov(df)
ef = EfficientFrontier(m, s)
weights = ef.max_sharpe()
cleaned_weights = ef.clean_weights()

ef.portfolio_performance(verbose=True)
print(dict(cleaned_weights))
# Out:
# Expected annual return: 66.6%
# Annual volatility: 78.6%
# Sharpe Ratio: 0.82
# {'ADA': 0.0, 'BCH': 0.0, 'BNB': 0.32633, 'BTC': 0.0, 'DOGE': 0.14001, 'ETH': 0.15124, 'LTC': 0.0, 'MATIC': 0.38242, 'TRX': 0.0, 'USDC': 0.0, 'USDT': 0.0, 'XRP': 0.0}

# %%
# Hierarchical Risk Parity

from pypfopt import HRPOpt

returns = close_df.pct_change().dropna()
hrp = HRPOpt(returns)
weights = hrp.optimize()
cleaned_weights = hrp.clean_weights()

hrp.portfolio_performance(verbose=True)
print(dict(cleaned_weights))
# Out:
# Expected annual return: 0.6%
# Annual volatility: 4.5%
# Sharpe Ratio: -0.31
# {'ADA': 0.00055, 'BCH': 0.00053, 'BNB': 0.00099, 'BTC': 0.00114, 'DOGE': 0.00034, 'ETH': 0.00068, 'LTC': 0.00104, 'MATIC': 0.00061, 'TRX': 0.00151, 'USDC': 0.47375, 'USDT': 0.51745, 'XRP': 0.00141}

# %%
# mCVAR

from pypfopt.efficient_frontier import EfficientCVaR

m = mean_historical_return(close_df)
s = close_df.cov()
ef_cvar = EfficientCVaR(m, s)
cvar_weights = ef_cvar.min_cvar()
cleaned_weights = ef_cvar.clean_weights()

ef_cvar.portfolio_performance(verbose=True)
print(dict(cleaned_weights))
# Out:
# Expected annual return: -0.1%
# Conditional Value at Risk: -0.00%
# {'ADA': 0.0, 'BCH': 0.0, 'BNB': 0.0, 'BTC': 0.0, 'DOGE': 0.0, 'ETH': 0.0, 'LTC': 0.0, 'MATIC': 0.0, 'TRX': 0.0, 'USDC': 0.13182, 'USDT': 0.86817, 'XRP': 0.0}

# %%
# sparse portfolio

import numpy as np

# Extract the columns of interest
symbols = prediction_df["symbol"]
returns = prediction_df["future_return"].to_numpy()
risks = prediction_df["future_risk"].to_numpy()

# Define the portfolio risk function
def portfolio_risk(w):
    return 0.5 * w.T @ np.diag(risks) @ w
# Define the portfolio return function
def portfolio_return(w):
    return w.T @ returns
# Define the gradient of the portfolio risk function
def portfolio_risk_grad(w):
    return np.diag(risks) @ w
# Define the projection onto the simplex
def project_simplex(w):
    u = np.sort(w)[::-1]
    cssv = np.cumsum(u)
    rho = np.nonzero(u * np.arange(1, len(u) + 1) > (cssv - 1))[0][-1]
    theta = (cssv[rho] - 1) / (rho + 1.0)
    return np.maximum(w - theta, 0)
# Define the thresholding operator
def threshold(w, k):
    idx = np.argsort(w)[::-1][:k]
    w_new = np.zeros_like(w)
    w_new[idx] = w[idx]
    return w_new

# Set the number of non-zero weights (e.g. 10)
k = 10
# Set the target portfolio return (e.g. 0.05)
r = 0.001
# Set the initial portfolio weights (e.g. uniform)
w = np.ones(len(symbols)) / len(symbols)
# Set the step size for gradient descent (e.g. 0.01)
alpha = 0.01
# Set the tolerance for convergence (e.g. 1e-6)
tol = 1e-6
# Set the maximum number of iterations (e.g. 1000)
max_iter = 10000
# Initialize the iteration counter and the convergence flag
iter = 0
converged = False
# Run the algorithm until convergence or maximum iterations
while not converged and iter < max_iter:
    # Save the current weights
    w_old = w.copy()
    # Update the weights using gradient descent
    w = w - alpha * portfolio_risk_grad(w)
    # Project the weights onto the simplex
    w = project_simplex(w)
    # Threshold the weights to enforce sparsity
    w = threshold(w, k)
    # Check the portfolio return constraint
    if portfolio_return(w) < r:
        # If violated, reset the weights to the previous ones
        w = w_old.copy()
        # Reduce the step size
        alpha = alpha / 2
    # Increment the iteration counter
    iter += 1
    # Check the convergence criterion
    if np.linalg.norm(w - w_old) < tol:
        # If satisfied, set the convergence flag to True
        converged = True
# Get the portfolio return and risk
portfolio_return = portfolio_return(w)
portfolio_risk = portfolio_risk(w)
# Print the results
print("The optimal sparse portfolio consists of the following stocks:")
for i in range(len(symbols)):
    if w[i] > 0:
        print(f"{symbols[i]}: {w[i]:.2f}")
print(f"The portfolio return is {portfolio_return:.4f} and the portfolio risk is {portfolio_risk:.4f}")
# Out:
# The optimal sparse portfolio consists of the following stocks:
# ADA: 0.10
# BNB: 0.08
# BTC: 0.09
# DOGE: 0.15
# ETH: 0.06
# MATIC: 0.05
# TRX: 0.07
# USDC: 0.16
# USDT: 0.16
# XRP: 0.08
# The portfolio return is 0.0214 and the portfolio risk is 0.0002
