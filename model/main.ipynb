# %% [markdown]
# # Import Modules and Config

# %%
import data_load
import clustering_model
import regression_model
# %load_ext autoreload
# %autoreload 2

# %%
UPDATE_DATA_LOAD = False
UPDATE_CLUSTERING_MODEL = True
UPDATE_REGRESSION_MODEL = True

# %% [markdown]
# # Data Load

# %%
basic_df = data_load.load_basic_data(
    selected_symbols=10, 
    max_date_added_year=2020, 
    min_last_update_year=2023, 
    min_market_pairs=6, 
    update=UPDATE_DATA_LOAD
)
print(basic_df.shape)
basic_df.head()
# Out:
# (10, 19)
#      id         name symbol      slug
# 0     1      Bitcoin    BTC   bitcoin  \
# 1  1027     Ethereum    ETH  ethereum
# 2   825  Tether USDt   USDT    tether
# 3  1839          BNB    BNB       bnb
# 4    52          XRP    XRP       xrp
#
#                                                 tags  cmcRank
# 0  ['mineable', 'pow', 'sha-256', 'store-of-value...        1  \
# 1  ['pos', 'smart-contracts', 'ethereum-ecosystem...        2
# 2  ['payments', 'stablecoin', 'asset-backed-stabl...        3
# 3  ['marketplace', 'centralized-exchange', 'payme...        4
# 4  ['medium-of-exchange', 'enterprise-solutions',...        5
#
#    marketPairCount  circulatingSupply  selfReportedCirculatingSupply
# 0            10493       1.951237e+07                              0  \
# 1             7546       1.202549e+08                              0
# 2            63642       8.352203e+10                              0
# 3             1679       1.538451e+08                              0
# 4             1113       5.344103e+10                              0
#
#     totalSupply     maxSupply  isActive               lastUpdated
# 0  1.951237e+07  2.100000e+07         1  2023-10-13T09:04:00.000Z  \
# 1  1.202549e+08           NaN         1  2023-10-13T09:04:00.000Z
# 2  8.662567e+10           NaN         1  2023-10-13T09:04:00.000Z
# 3  1.538451e+08           NaN         1  2023-10-13T09:04:00.000Z
# 4  9.998836e+10  1.000000e+11         1  2023-10-13T09:04:00.000Z
#
#                   dateAdded
# 0  2010-07-13T00:00:00.000Z  \
# 1  2015-08-07T00:00:00.000Z
# 2  2015-02-25T00:00:00.000Z
# 3  2017-07-25T00:00:00.000Z
# 4  2013-08-04T00:00:00.000Z
#
#                                               quotes  isAudited  badges
# 0  [{'name': 'USD', 'price': 26800.522640046795, ...      False     [1]  \
# 1  [{'name': 'USD', 'price': 1548.4278234952615, ...      False  [1, 4]
# 2  [{'name': 'USD', 'price': 0.999723105320604, '...       True      []
# 3  [{'name': 'USD', 'price': 205.77786499801198, ...       True  [1, 3]
# 4  [{'name': 'USD', 'price': 0.4819245630066666, ...       True  [1, 3]
#
#                                        auditInfoList
# 0                                                NaN  \
# 1                                                 []
# 2  [{'coinId': '825', 'auditor': 'CertiK', 'audit...
# 3  [{'coinId': '1839', 'auditor': 'CertiK', 'audi...
# 4  [{'coinId': '52', 'auditor': 'CertiK', 'auditS...
#
#                                             platform
# 0                                                NaN
# 1                                                NaN
# 2  {'id': 1, 'name': 'Ethereum', 'symbol': 'ETH',...
# 3                                                NaN
# 4                                                NaN

# %%
symbols_list = basic_df["symbol"].to_list()
historical_df = data_load.load_historical_data(
    symbols_list,
    update=UPDATE_DATA_LOAD
)
print(historical_df.shape)
historical_df.head()
# Out:
# (26597, 10)
#   symbol        date          open          high           low         close
# 0    BTC  2023-10-12  26873.292491  26921.438903  26558.320784  26756.798639  \
# 1    BTC  2023-10-11  27392.075546  27474.116187  26561.099366  26873.321121
# 2    BTC  2023-10-10  27589.201102  27715.848347  27301.655078  27391.019517
# 3    BTC  2023-10-09  27934.472162  27989.470902  27302.561919  27583.678595
# 4    BTC  2023-10-08  27971.678107  28102.170391  27740.663024  27935.089581
#
#             avg    return        volume     marketcap
# 0  26815.045565 -0.004335  9.392909e+09  5.220780e+11
# 1  27132.698333 -0.018938  1.364809e+10  5.243250e+11
# 2  27490.110310 -0.007183  9.973351e+09  5.343984e+11
# 3  27759.075379 -0.012558  1.200767e+10  5.381279e+11
# 4  27953.383844 -0.001308  7.916875e+09  5.449575e+11

# %%
selected_df = data_load.load_selected_data(
    historical_df, 
    selected_days=1460, 
    end_date="2023-10-10", 
    update=UPDATE_DATA_LOAD
)
print(selected_df.shape)
selected_df.head()
# Out:
# (13140, 10)
#   symbol        date          open          high           low         close
# 0    BTC  2023-10-10  27589.201102  27715.848347  27301.655078  27391.019517  \
# 1    BTC  2023-10-09  27934.472162  27989.470902  27302.561919  27583.678595
# 2    BTC  2023-10-08  27971.678107  28102.170391  27740.663024  27935.089581
# 3    BTC  2023-10-07  27946.781633  28028.092087  27870.423458  27968.838871
# 4    BTC  2023-10-06  27412.122424  28252.537570  27215.552446  27946.596780
#
#             avg    return        volume     marketcap
# 0  27490.110310 -0.007183  9.973351e+09  5.343984e+11
# 1  27759.075379 -0.012558  1.200767e+10  5.381279e+11
# 2  27953.383844 -0.001308  7.916875e+09  5.449575e+11
# 3  27957.810252  0.000789  6.553044e+09  5.455899e+11
# 4  27679.359602  0.019498  1.349239e+10  5.451267e+11

# %% [markdown]
# # Clustering Model

# %%
# TODO: Add a KPI to measure how much the model worked

# %%
return_df = clustering_model.load_return_data(
    selected_df, 
    update=UPDATE_CLUSTERING_MODEL
)
print(return_df.shape)
return_df.head()
# Out:
# return data file saved.
# (1460, 9)
#                  ADA       BNB       BTC      DOGE       ETH       TRX
# 2019-10-12  0.000053  0.033728  0.002512  0.005015 -0.009354 -0.016072  \
# 2019-10-13  0.019357  0.060925 -0.001907  0.046538  0.006711  0.025739
# 2019-10-14  0.011243  0.008273  0.006472  0.039529  0.027097  0.036808
# 2019-10-15 -0.048566  0.006446 -0.020074 -0.014151 -0.029795 -0.058775
# 2019-10-16 -0.025635 -0.036556 -0.019153  0.039411 -0.029393 -0.028902
#
#                 USDC      USDT       XRP
# 2019-10-12 -0.004148 -0.007881  0.007657
# 2019-10-13  0.000226  0.000532  0.016974
# 2019-10-14 -0.000418 -0.000642  0.068065
# 2019-10-15  0.001337 -0.000194 -0.026097
# 2019-10-16  0.000364  0.002089 -0.014730

# %%
clusters_df = clustering_model.load_clusters_data(
    return_df, 
    UPDATE_CLUSTERING_MODEL
)
print(clusters_df['cluster'].unique().shape)
clusters_df.head()
# Out:
# Clusters data file saved.
# (3,)
#   symbol cluster
# 0   DOGE       0
# 1    ADA       1
# 2    BNB       1
# 3    BTC       1
# 4    ETH       1

# %% [markdown]
# # Regression Model

# %%
# TODO: Create a dataframe which has the predicted return and risk for each symbol
# TODO: Use ANN models
# TODO: Add financial indexes to regression model
# TODO: Add more regression models (LogisticRegression(), SVC(kernel='poly', probability=True), XGBClassifier(), etc)
# TODO: Grid search over parameters

# %%
regression_df = regression_model.load_regression_data(
    selected_df, 
    clusters_df, 
    future_days=30, 
    update=UPDATE_REGRESSION_MODEL
)
print(regression_df.shape)
regression_df.head()
# Out:
# (12870, 27)
#    future_return  future_risk      open      high       low     close
# 0       0.051702     0.024500  0.383350  0.377646  0.386253  0.382321  \
# 1       0.055933     0.023589  0.383501  0.376830  0.388817  0.383260
# 2       0.066892     0.024524  0.388532  0.383982  0.386814  0.383408
# 3       0.056419     0.025652  0.381176  0.383914  0.385770  0.388359
# 4       0.072685     0.024508  0.381703  0.377281  0.382699  0.381152
#
#         avg    return    volume  marketcap  ...  symbol_BTC  symbol_DOGE
# 0  0.384529 -0.012939  0.022508   0.394765  ...        True        False  \
# 1  0.385077 -0.002002  0.015618   0.395715  ...        True        False
# 2  0.387677 -0.068828  0.030821   0.395849  ...        True        False
# 3  0.386470  0.101629  0.031594   0.400943  ...        True        False
# 4  0.383115 -0.006333  0.036336   0.393485  ...        True        False
#
#    symbol_ETH  symbol_TRX  symbol_USDC  symbol_USDT  symbol_XRP  cluster_0
# 0       False       False        False        False       False      False  \
# 1       False       False        False        False       False      False
# 2       False       False        False        False       False      False
# 3       False       False        False        False       False      False
# 4       False       False        False        False       False      False
#
#    cluster_1  cluster_2
# 0       True      False
# 1       True      False
# 2       True      False
# 3       True      False
# 4       True      False
#
# [5 rows x 27 columns]

# %%
# regression_df.plot.scatter(x='close', y='future_return')

# %%
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
x = regression_df.loc[:, 'open':]
y = regression_df[['future_return', 'future_risk']]
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size = 0.2, random_state = 4)

# %%
regr = linear_model.LinearRegression()
regr.fit(train_x, train_y)

train_y_ = regr.predict(train_x)
print(f'Train R2: {(100 * r2_score(train_y, train_y_)):.2f}%')
test_y_ = regr.predict(test_x)
print(f'Test R2: {(100 * r2_score(test_y, test_y_)):.2f}%')
# Out:
# Train R2: 20.26%
# Test R2: 20.55%

# %%
regr = RandomForestRegressor(n_estimators=100)
regr.fit(train_x, train_y)

train_y_ = regr.predict(train_x)
print(f'Train R2: {(100 * r2_score(train_y, train_y_)):.2f}%')
test_y_ = regr.predict(test_x)
print(f'Test R2: {(100 * r2_score(test_y, test_y_)):.2f}%')
# Out:
# Train R2: 97.80%
# Test R2: 85.19%

# %% [markdown]
# # Portfolio Selection

# %%
# TODO: Use clustering models
# TODO: Add CAPM Model
# TODO: Add Black-Litterman allocation?
# TODO: long and short? weight_bounds=(-1, 1)

# %%
close_df = selected_df[["date", "symbol", "close"]]
close_df = close_df.pivot(index="date", columns="symbol")
close_df = close_df["close"]
close_df.columns.name = None
close_df

# %%
# Mean Variance

from pypfopt.expected_returns import mean_historical_return
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.efficient_frontier import EfficientFrontier

m = mean_historical_return(close_df)  # mu = expected_returns.mean_historical_return(df)
s = CovarianceShrinkage(close_df).ledoit_wolf()  # S = risk_models.sample_cov(df)
ef = EfficientFrontier(m, s)
weights = ef.max_sharpe()
cleaned_weights = ef.clean_weights()

ef.portfolio_performance(verbose=True)
print(dict(cleaned_weights))

# %%
# Hierarchical Risk Parity

from pypfopt import HRPOpt

returns = close_df.pct_change().dropna()
hrp = HRPOpt(returns)
weights = hrp.optimize()
cleaned_weights = hrp.clean_weights()

hrp.portfolio_performance(verbose=True)
print(dict(cleaned_weights))

# %%
# mCVAR

from pypfopt.efficient_frontier import EfficientCVaR

m = mean_historical_return(close_df)
s = close_df.cov()
ef_cvar = EfficientCVaR(m, s)
cvar_weights = ef_cvar.min_cvar()
cleaned_weights = ef_cvar.clean_weights()

ef_cvar.portfolio_performance(verbose=True)
print(dict(cleaned_weights))
